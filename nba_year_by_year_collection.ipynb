# %% [markdown]
# # NBA Game Data Collection - Year by Year Processing
# ## Optimized for 7,500 Requests/Day
#
# This notebook:
# 1. Processes ONE season at a time
# 2. Saves each season to a separate CSV
# 3. Calculates all team-level features
# 4. Includes proper target variable (team_won) for XGBoost
# 5. Handles 7,500 requests/day efficiently

# %% [markdown]
# ## Configuration

# %%
import requests
import pandas as pd
import numpy as np
import os
import json
import time
from datetime import datetime
from dotenv import load_dotenv
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Select which season to process
SEASON_TO_PROCESS = 2020  # Change this to process different seasons: 2018, 2019, 2020, 2021, 2022, 2023, or 2024

# API Configuration
load_dotenv()
API_KEY = os.getenv("RAPIDAPI_KEY")
API_HOST = "v2.nba.api-sports.io"
BASE_URL = "https://v2.nba.api-sports.io"

HEADERS = {
    "X-RapidAPI-Key": API_KEY,
    "X-RapidAPI-Host": API_HOST
}

# Output directory for year-specific CSVs
OUTPUT_DIR = "nba_features_by_year"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Cache directory
CACHE_DIR = f"nba_cache_{SEASON_TO_PROCESS}"
os.makedirs(CACHE_DIR, exist_ok=True)

print(f"{'='*70}")
print(f"NBA DATA COLLECTION - SEASON {SEASON_TO_PROCESS}")
print(f"{'='*70}")
print(f"API Rate Limit: 7,500 requests/day")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Cache directory: {CACHE_DIR}")
print(f"\nProcessing Season: {SEASON_TO_PROCESS}")
# Out:
# ======================================================================
# NBA DATA COLLECTION - SEASON 2020
# ======================================================================
# API Rate Limit: 7,500 requests/day
# Output directory: nba_features_by_year
# Cache directory: nba_cache_2020
#
# Processing Season: 2020

# %% [markdown]
# ## API Helper Functions

# %%
def get_cache_path(endpoint, params):
    """Generate cache file path"""
    param_str = '_'.join([f"{k}-{v}" for k, v in sorted(params.items())])
    filename = f"{endpoint.replace('/', '_')}_{param_str}.json"
    return os.path.join(CACHE_DIR, filename)

def load_from_cache(cache_path):
    """Load from cache if exists"""
    if os.path.exists(cache_path):
        with open(cache_path, 'r') as f:
            return json.load(f)
    return None

def save_to_cache(cache_path, data):
    """Save to cache"""
    with open(cache_path, 'w') as f:
        json.dump(data, f, indent=2)

def make_api_request(endpoint, params=None, use_cache=True):
    """
    Make API request with caching.
    With 7,500 requests/day, we have ~5 requests/second available.
    """
    if params is None:
        params = {}
    
    # Check cache
    cache_path = get_cache_path(endpoint, params)
    if use_cache:
        cached_data = load_from_cache(cache_path)
        if cached_data:
            logging.info(f"✓ Cache hit: {endpoint}")
            return cached_data
    
    # Make request
    url = f"{BASE_URL}/{endpoint}"
    
    try:
        response = requests.get(url, headers=HEADERS, params=params)
        response.raise_for_status()
        data = response.json()
        
        # Save to cache
        save_to_cache(cache_path, data)
        
        # Rate limiting: 0.2 seconds between requests (5 req/sec)
        time.sleep(0.2)
        
        remaining = response.headers.get('x-ratelimit-requests-remaining', 'N/A')
        logging.info(f"✓ API call successful. Remaining today: {remaining}")
        
        return data
        
    except requests.exceptions.RequestException as e:
        logging.error(f"✗ Error: {e}")
        return None

print("✓ API functions ready")
# Out:
# ✓ API functions ready

# %% [markdown]
# ## Step 1: Collect All Games for Selected Season

# %%
def collect_games_for_season(season):
    """
    Collect all games for a specific season.
    Returns DataFrame with game metadata including winner.
    """
    logging.info(f"\n{'='*70}")
    logging.info(f"Collecting games for season {season}")
    logging.info(f"{'='*70}")
    
    games_data = make_api_request("games", params={
        "season": season,
        "league": "standard"
    })
    
    if not games_data or 'response' not in games_data:
        logging.error(f"Failed to fetch games for season {season}")
        return pd.DataFrame()
    
    games_list = games_data['response']
    
    # Extract game information with winner
    completed_games = []
    for game in games_list:
        home_score = game.get('scores', {}).get('home', {}).get('points')
        away_score = game.get('scores', {}).get('visitors', {}).get('points')
        
        # Only include completed games with scores
        if home_score is not None and away_score is not None:
            home_team_id = game.get('teams', {}).get('home', {}).get('id')
            away_team_id = game.get('teams', {}).get('visitors', {}).get('id')
            
            # Determine winner
            winning_team_id = home_team_id if home_score > away_score else away_team_id
            
            completed_games.append({
                'game_id': game['id'],
                'season': season,
                'date': game.get('date', {}).get('start', ''),
                'home_team_id': home_team_id,
                'away_team_id': away_team_id,
                'home_score': home_score,
                'away_score': away_score,
                'winning_team_id': winning_team_id
            })
    
    games_df = pd.DataFrame(completed_games)
    
    logging.info(f"✓ Found {len(games_df)} completed games for season {season}")
    logging.info(f"  Date range: {games_df['date'].min()} to {games_df['date'].max()}")
    
    return games_df

# Collect games for selected season
print(f"\n🏀 Collecting games for season {SEASON_TO_PROCESS}...\n")
games_df = collect_games_for_season(SEASON_TO_PROCESS)

print(f"\n✓ Game collection complete!")
print(f"Total games: {len(games_df)}")
print(f"\nSample games:")
games_df.head()
# Out:
# 2025-11-23 18:25:40,595 - INFO -
# ======================================================================
# 2025-11-23 18:25:40,596 - INFO - Collecting games for season 2020
# 2025-11-23 18:25:40,596 - INFO - ======================================================================
# 🏀 Collecting games for season 2020...
# 2025-11-23 18:25:41,864 - INFO - ✓ API call successful. Remaining today: 7499
# 2025-11-23 18:25:41,887 - INFO - ✓ Found 1221 completed games for season 2020
# 2025-11-23 18:25:41,898 - INFO -   Date range: 2020-12-12T00:00:00.000Z to 2021-07-21T01:00:00.000Z
# ✓ Game collection complete!
# Total games: 1221
#
# Sample games:
#    game_id  season                      date  home_team_id  away_team_id  \
# 0     7501    2020  2020-12-19T01:00:00.000Z             2             4
# 1     7502    2020  2020-12-19T01:00:00.000Z            23            21
# 2     7503    2020  2020-12-19T01:00:00.000Z            25             6
# 3     7504    2020  2020-12-19T02:00:00.000Z             9            29
# 4     7505    2020  2020-12-19T03:30:00.000Z            28            17
#
#    home_score  away_score  winning_team_id
# 0          89         113                4
# 1         127         113               23
# 2         103         105                6
# 3         129          96                9
# 4         113         114               17

# %% [markdown]
# ## Step 2: Feature Engineering Functions
#
# These match your original notebook exactly

# %%
def convert_minutes_to_numeric(minutes_str):
    """
    Convert minutes from 'MM:SS' format to decimal.
    Example: '25:30' -> 25.5
    """
    if pd.isna(minutes_str) or minutes_str == '0' or minutes_str == 0:
        return 0.0
    
    try:
        if isinstance(minutes_str, str) and ':' in minutes_str:
            parts = minutes_str.split(':')
            mins = float(parts[0])
            secs = float(parts[1]) if len(parts) > 1 else 0
            return mins + (secs / 60.0)
        else:
            return float(minutes_str)
    except:
        return 0.0

def calculate_all_team_features(player_stats_df):
    """
    Calculate ALL team-level features from player statistics.
    Includes features from: Sanika, Aditya, Dev, and Chinmayee.
    """
    df = player_stats_df.copy()
    
    # Convert percentage columns to float
    percentage_cols = ['fg_pct', 'three_pct', 'ft_pct']
    for col in percentage_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)
    
    # Convert plus_minus to numeric
    df['plus_minus'] = pd.to_numeric(df['plus_minus'], errors='coerce').fillna(0)
    
    # Convert minutes
    df['minutes_numeric'] = df['minutes'].apply(convert_minutes_to_numeric)
    
    # Convert other numeric fields
    numeric_cols = ['points', 'total_rebounds', 'assists', 'steals', 'blocks', 
                   'turnovers', 'personal_fouls', 'fg_made', 'fg_attempted',
                   'three_made', 'three_attempted', 'ft_made', 'ft_attempted',
                   'offensive_reb', 'defensive_reb']
    
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)
    
    # Filter to only players who played (minutes > 0)
    df_played = df[df['minutes_numeric'] > 0].copy()
    
    # Define aggregation dictionary - ALL features
    agg_dict = {
        # Sanika's features - shooting metrics
        'ft_pct': 'mean',
        'fg_made': ['sum', 'mean'],
        'fg_attempted': ['sum', 'mean'],
        'three_made': ['sum', 'mean'],
        'three_attempted': ['sum', 'mean'],
        'ft_made': ['sum', 'mean'],
        
        # Aditya's features
        'ft_attempted': ['sum', 'mean'],
        'minutes_numeric': ['sum', 'mean', 'max'],
        
        # Dev's features
        'points': ['sum', 'mean', 'std', 'max'],
        'assists': ['sum', 'mean', 'std', 'max'],
        'total_rebounds': ['sum', 'mean', 'std', 'max'],
        'offensive_reb': ['sum', 'mean'],
        'defensive_reb': ['sum', 'mean'],
        'steals': ['sum', 'mean'],
        
        # Chinmayee's features
        'blocks': ['sum', 'mean'],
        'turnovers': ['sum', 'mean'],
        'personal_fouls': ['sum', 'mean'],
        'plus_minus': ['sum', 'mean'],
        'fg_pct': 'mean',
        'three_pct': 'mean',
        
        # Identifiers
        'team_name': 'first',
        'season': 'first'
    }
    
    # Group by game and team
    team_features = df_played.groupby(['game_id', 'team_id']).agg(agg_dict).reset_index()
    
    # Flatten column names
    team_features.columns = ['_'.join(col).strip('_') if isinstance(col, tuple) else col 
                             for col in team_features.columns.values]
    
    # Clean up names
    team_features.columns = [col.replace('_first', '') for col in team_features.columns]
    
    # Rename minutes columns
    rename_map = {
        'minutes_numeric_sum': 'minutes_sum',
        'minutes_numeric_mean': 'minutes_mean',
        'minutes_numeric_max': 'minutes_max'
    }
    team_features = team_features.rename(columns=rename_map)
    
    # Calculate Aditya's engineered features
    team_features['assist_to_turnover_ratio'] = team_features.apply(
        lambda row: row['assists_sum'] / row['turnovers_sum'] 
        if row['turnovers_sum'] > 0 else row['assists_sum'],
        axis=1
    )
    
    team_features['three_point_rate'] = team_features.apply(
        lambda row: row['three_made_sum'] / row['fg_made_sum']
        if row['fg_made_sum'] > 0 else 0.0,
        axis=1
    )
    
    team_features['offensive_reb_rate'] = team_features.apply(
        lambda row: row['offensive_reb_sum'] / row['total_rebounds_sum']
        if row['total_rebounds_sum'] > 0 else 0.0,
        axis=1
    )
    
    team_features['true_shooting_pct'] = team_features.apply(
        lambda row: (row['points_sum'] / 
                    (2 * (row['fg_attempted_sum'] + 0.44 * row['ft_attempted_sum'])))
        if (row['fg_attempted_sum'] + 0.44 * row['ft_attempted_sum']) > 0 else 0.0,
        axis=1
    )
    
    return team_features

print("✓ Feature engineering functions ready")
# Out:
# ✓ Feature engineering functions ready

# %% [markdown]
# ## Step 3: Fetch Player Statistics for All Games
#
# With 7,500 requests/day, a typical season (~1,230 games) takes about 3-4 hours

# %%
def fetch_player_stats_for_game(game_id):
    """
    Fetch player statistics for a single game.
    """
    player_stats_data = make_api_request("players/statistics", params={"game": game_id})
    
    if not player_stats_data or 'response' not in player_stats_data:
        return []
    
    records = []
    for stat in player_stats_data['response']:
        record = {
            'game_id': game_id,
            'season': SEASON_TO_PROCESS,
            'player_id': stat['player']['id'],
            'player_name': stat['player']['firstname'] + ' ' + stat['player']['lastname'],
            'team_id': stat['team']['id'],
            'team_name': stat['team']['name'],
            'position': stat.get('pos', 'N/A'),
            'minutes': stat.get('min', '0'),
            'points': stat.get('points', 0),
            'total_rebounds': stat.get('totReb', 0),
            'assists': stat.get('assists', 0),
            'steals': stat.get('steals', 0),
            'blocks': stat.get('blocks', 0),
            'turnovers': stat.get('turnovers', 0),
            'personal_fouls': stat.get('pFouls', 0),
            'fg_made': stat.get('fgm', 0),
            'fg_attempted': stat.get('fga', 0),
            'fg_pct': stat.get('fgp', '0'),
            'three_made': stat.get('tpm', 0),
            'three_attempted': stat.get('tpa', 0),
            'three_pct': stat.get('tpp', '0'),
            'ft_made': stat.get('ftm', 0),
            'ft_attempted': stat.get('fta', 0),
            'ft_pct': stat.get('ftp', '0'),
            'offensive_reb': stat.get('offReb', 0),
            'defensive_reb': stat.get('defReb', 0),
            'plus_minus': stat.get('plusMinus', '0'),
        }
        records.append(record)
    
    return records

def process_all_games(games_df):
    """
    Process all games: fetch stats and calculate features.
    """
    total_games = len(games_df)
    game_ids = games_df['game_id'].tolist()
    
    logging.info(f"\n{'='*70}")
    logging.info(f"Processing {total_games} games")
    logging.info(f"Estimated time: {total_games * 0.2 / 60:.1f} minutes")
    logging.info(f"{'='*70}\n")
    
    all_player_stats = []
    start_time = time.time()
    
    for idx, game_id in enumerate(game_ids, 1):
        player_stats = fetch_player_stats_for_game(game_id)
        all_player_stats.extend(player_stats)
        
        # Progress updates
        if idx % 50 == 0 or idx == total_games:
            elapsed = time.time() - start_time
            games_per_sec = idx / elapsed if elapsed > 0 else 0
            remaining_games = total_games - idx
            eta_seconds = remaining_games / games_per_sec if games_per_sec > 0 else 0
            
            logging.info(f"Progress: {idx}/{total_games} games ({idx/total_games*100:.1f}%) | "
                        f"Speed: {games_per_sec:.1f} games/sec | "
                        f"ETA: {eta_seconds/60:.1f} min")
    
    if not all_player_stats:
        logging.error("No player stats collected!")
        return pd.DataFrame()
    
    # Convert to DataFrame
    player_stats_df = pd.DataFrame(all_player_stats)
    
    logging.info(f"\n✓ Player stats collected: {len(player_stats_df)} records")
    logging.info(f"  Total time: {(time.time() - start_time)/60:.1f} minutes")
    
    # Calculate team features
    logging.info(f"\nCalculating team features...")
    team_features_df = calculate_all_team_features(player_stats_df)
    
    logging.info(f"✓ Team features calculated: {len(team_features_df)} teams")
    
    return team_features_df

# Process all games for this season
print(f"\n🎯 Processing all games for season {SEASON_TO_PROCESS}...\n")
team_features_df = process_all_games(games_df)

print(f"\n✓ Feature calculation complete!")
print(f"Total team records: {len(team_features_df)}")
print(f"Features calculated: {len(team_features_df.columns) - 3}")  # Exclude game_id, team_id, season
# Out:
# 2025-11-23 18:25:41,930 - INFO -
# ======================================================================
# 2025-11-23 18:25:41,931 - INFO - Processing 1221 games
# 2025-11-23 18:25:41,932 - INFO - Estimated time: 4.1 minutes
# 2025-11-23 18:25:41,933 - INFO - ======================================================================
# 🎯 Processing all games for season 2020...
# 2025-11-23 18:25:42,440 - INFO - ✓ API call successful. Remaining today: 7498
# 2025-11-23 18:25:42,984 - INFO - ✓ API call successful. Remaining today: 7497
# 2025-11-23 18:25:43,493 - INFO - ✓ API call successful. Remaining today: 7496
# 2025-11-23 18:25:44,018 - INFO - ✓ API call successful. Remaining today: 7495
# 2025-11-23 18:25:44,571 - INFO - ✓ API call successful. Remaining today: 7494
# 2025-11-23 18:25:45,099 - INFO - ✓ API call successful. Remaining today: 7493
# 2025-11-23 18:25:45,609 - INFO - ✓ API call successful. Remaining today: 7492
# 2025-11-23 18:25:46,336 - INFO - ✓ API call successful. Remaining today: 7491
# 2025-11-23 18:25:46,835 - INFO - ✓ API call successful. Remaining today: 7490
# 2025-11-23 18:25:47,348 - INFO - ✓ API call successful. Remaining today: 7489
# 2025-11-23 18:25:47,863 - INFO - ✓ API call successful. Remaining today: 7488
# 2025-11-23 18:25:48,369 - INFO - ✓ API call successful. Remaining today: 7487
# 2025-11-23 18:25:48,867 - INFO - ✓ API call successful. Remaining today: 7486
# 2025-11-23 18:25:49,390 - INFO - ✓ API call successful. Remaining today: 7485
# 2025-11-23 18:25:49,912 - INFO - ✓ API call successful. Remaining today: 7484
# 2025-11-23 18:25:50,417 - INFO - ✓ API call successful. Remaining today: 7483
# 2025-11-23 18:25:50,937 - INFO - ✓ API call successful. Remaining today: 7482
# 2025-11-23 18:25:51,453 - INFO - ✓ API call successful. Remaining today: 7481
# 2025-11-23 18:25:51,978 - INFO - ✓ API call successful. Remaining today: 7480
# 2025-11-23 18:25:52,497 - INFO - ✓ API call successful. Remaining today: 7479
# 2025-11-23 18:25:53,110 - INFO - ✓ API call successful. Remaining today: 7478
# 2025-11-23 18:25:53,647 - INFO - ✓ API call successful. Remaining today: 7477
# 2025-11-23 18:25:54,149 - INFO - ✓ API call successful. Remaining today: 7476
# 2025-11-23 18:25:54,661 - INFO - ✓ API call successful. Remaining today: 7475
# 2025-11-23 18:25:55,175 - INFO - ✓ API call successful. Remaining today: 7474
# 2025-11-23 18:25:55,669 - INFO - ✓ API call successful. Remaining today: 7473
# 2025-11-23 18:25:56,172 - INFO - ✓ API call successful. Remaining today: 7472
# 2025-11-23 18:25:56,676 - INFO - ✓ API call successful. Remaining today: 7471
# 2025-11-23 18:25:57,188 - INFO - ✓ API call successful. Remaining today: 7470
# 2025-11-23 18:25:57,703 - INFO - ✓ API call successful. Remaining today: 7469
# 2025-11-23 18:25:58,213 - INFO - ✓ API call successful. Remaining today: 7468
# 2025-11-23 18:25:58,728 - INFO - ✓ API call successful. Remaining today: 7467
# 2025-11-23 18:25:59,315 - INFO - ✓ API call successful. Remaining today: 7466
# 2025-11-23 18:25:59,833 - INFO - ✓ API call successful. Remaining today: 7465
# 2025-11-23 18:26:00,349 - INFO - ✓ API call successful. Remaining today: 7464
# 2025-11-23 18:26:00,859 - INFO - ✓ API call successful. Remaining today: 7499
# 2025-11-23 18:26:01,375 - INFO - ✓ API call successful. Remaining today: 7498
# 2025-11-23 18:26:01,904 - INFO - ✓ API call successful. Remaining today: 7497
# 2025-11-23 18:26:02,445 - INFO - ✓ API call successful. Remaining today: 7496
# 2025-11-23 18:26:02,945 - INFO - ✓ API call successful. Remaining today: 7495
# 2025-11-23 18:26:03,462 - INFO - ✓ API call successful. Remaining today: 7494
# 2025-11-23 18:26:03,986 - INFO - ✓ API call successful. Remaining today: 7493
# 2025-11-23 18:26:04,503 - INFO - ✓ API call successful. Remaining today: 7492
# 2025-11-23 18:26:05,145 - INFO - ✓ API call successful. Remaining today: 7491
# 2025-11-23 18:26:05,672 - INFO - ✓ API call successful. Remaining today: 7490
# 2025-11-23 18:26:06,181 - INFO - ✓ API call successful. Remaining today: 7489
# 2025-11-23 18:26:06,695 - INFO - ✓ API call successful. Remaining today: 7488
# 2025-11-23 18:26:07,213 - INFO - ✓ API call successful. Remaining today: 7487
# 2025-11-23 18:26:07,725 - INFO - ✓ API call successful. Remaining today: 7486
# 2025-11-23 18:26:08,250 - INFO - ✓ API call successful. Remaining today: 7485
# 2025-11-23 18:26:08,253 - INFO - Progress: 50/1221 games (4.1%) | Speed: 1.9 games/sec | ETA: 10.3 min
# 2025-11-23 18:26:08,775 - INFO - ✓ API call successful. Remaining today: 7484
# 2025-11-23 18:26:09,303 - INFO - ✓ API call successful. Remaining today: 7483
# 2025-11-23 18:26:09,813 - INFO - ✓ API call successful. Remaining today: 7482
# 2025-11-23 18:26:10,323 - INFO - ✓ API call successful. Remaining today: 7481
# 2025-11-23 18:26:10,889 - INFO - ✓ API call successful. Remaining today: 7480
# 2025-11-23 18:26:11,405 - INFO - ✓ API call successful. Remaining today: 7479
# 2025-11-23 18:26:11,919 - INFO - ✓ API call successful. Remaining today: 7478
# 2025-11-23 18:26:12,428 - INFO - ✓ API call successful. Remaining today: 7477
# 2025-11-23 18:26:12,959 - INFO - ✓ API call successful. Remaining today: 7476
# 2025-11-23 18:26:13,477 - INFO - ✓ API call successful. Remaining today: 7475
# 2025-11-23 18:26:13,991 - INFO - ✓ API call successful. Remaining today: 7474
# 2025-11-23 18:26:14,502 - INFO - ✓ API call successful. Remaining today: 7473
# 2025-11-23 18:26:15,016 - INFO - ✓ API call successful. Remaining today: 7472
# 2025-11-23 18:26:15,524 - INFO - ✓ API call successful. Remaining today: 7471
# 2025-11-23 18:26:16,037 - INFO - ✓ API call successful. Remaining today: 7470
# 2025-11-23 18:26:16,550 - INFO - ✓ API call successful. Remaining today: 7469
# 2025-11-23 18:26:17,051 - INFO - ✓ API call successful. Remaining today: 7468
# 2025-11-23 18:26:17,567 - INFO - ✓ API call successful. Remaining today: 7467
# 2025-11-23 18:26:18,085 - INFO - ✓ API call successful. Remaining today: 7466
# 2025-11-23 18:26:18,595 - INFO - ✓ API call successful. Remaining today: 7465
# 2025-11-23 18:26:19,098 - INFO - ✓ API call successful. Remaining today: 7464
# 2025-11-23 18:26:19,608 - INFO - ✓ API call successful. Remaining today: 7463
# 2025-11-23 18:26:20,124 - INFO - ✓ API call successful. Remaining today: 7462
# 2025-11-23 18:26:20,638 - INFO - ✓ API call successful. Remaining today: 7461
# 2025-11-23 18:26:21,152 - INFO - ✓ API call successful. Remaining today: 7460
# 2025-11-23 18:26:21,668 - INFO - ✓ API call successful. Remaining today: 7459
# 2025-11-23 18:26:22,185 - INFO - ✓ API call successful. Remaining today: 7458
# 2025-11-23 18:26:22,692 - INFO - ✓ API call successful. Remaining today: 7457
# 2025-11-23 18:26:23,208 - INFO - ✓ API call successful. Remaining today: 7456
# 2025-11-23 18:26:23,737 - INFO - ✓ API call successful. Remaining today: 7455
# 2025-11-23 18:26:24,250 - INFO - ✓ API call successful. Remaining today: 7454
# 2025-11-23 18:26:24,781 - INFO - ✓ API call successful. Remaining today: 7453
# 2025-11-23 18:26:25,284 - INFO - ✓ API call successful. Remaining today: 7452
# 2025-11-23 18:26:25,809 - INFO - ✓ API call successful. Remaining today: 7451
# 2025-11-23 18:26:26,320 - INFO - ✓ API call successful. Remaining today: 7450
# 2025-11-23 18:26:26,833 - INFO - ✓ API call successful. Remaining today: 7449
# 2025-11-23 18:26:27,349 - INFO - ✓ API call successful. Remaining today: 7448
# 2025-11-23 18:26:27,863 - INFO - ✓ API call successful. Remaining today: 7447
# 2025-11-23 18:26:28,375 - INFO - ✓ API call successful. Remaining today: 7446
# 2025-11-23 18:26:28,880 - INFO - ✓ API call successful. Remaining today: 7445
# 2025-11-23 18:26:29,413 - INFO - ✓ API call successful. Remaining today: 7444
# 2025-11-23 18:26:29,935 - INFO - ✓ API call successful. Remaining today: 7443
# 2025-11-23 18:26:30,467 - INFO - ✓ API call successful. Remaining today: 7442
# 2025-11-23 18:26:30,973 - INFO - ✓ API call successful. Remaining today: 7441
# 2025-11-23 18:26:31,472 - INFO - ✓ API call successful. Remaining today: 7440
# 2025-11-23 18:26:31,992 - INFO - ✓ API call successful. Remaining today: 7439
# 2025-11-23 18:26:32,503 - INFO - ✓ API call successful. Remaining today: 7438
# 2025-11-23 18:26:33,022 - INFO - ✓ API call successful. Remaining today: 7437
# 2025-11-23 18:26:33,558 - INFO - ✓ API call successful. Remaining today: 7436
# 2025-11-23 18:26:34,059 - INFO - ✓ API call successful. Remaining today: 7435
# 2025-11-23 18:26:34,063 - INFO - Progress: 100/1221 games (8.2%) | Speed: 1.9 games/sec | ETA: 9.7 min
# 2025-11-23 18:26:34,582 - INFO - ✓ API call successful. Remaining today: 7434
# 2025-11-23 18:26:35,094 - INFO - ✓ API call successful. Remaining today: 7433
# 2025-11-23 18:26:35,605 - INFO - ✓ API call successful. Remaining today: 7432
# 2025-11-23 18:26:36,110 - INFO - ✓ API call successful. Remaining today: 7431
# 2025-11-23 18:26:36,624 - INFO - ✓ API call successful. Remaining today: 7430
# 2025-11-23 18:26:37,133 - INFO - ✓ API call successful. Remaining today: 7429
# 2025-11-23 18:26:37,636 - INFO - ✓ API call successful. Remaining today: 7428
# 2025-11-23 18:26:38,149 - INFO - ✓ API call successful. Remaining today: 7427
# 2025-11-23 18:26:38,661 - INFO - ✓ API call successful. Remaining today: 7426
# 2025-11-23 18:26:39,168 - INFO - ✓ API call successful. Remaining today: 7425
# 2025-11-23 18:26:39,666 - INFO - ✓ API call successful. Remaining today: 7424
# 2025-11-23 18:26:40,165 - INFO - ✓ API call successful. Remaining today: 7423
# 2025-11-23 18:26:40,666 - INFO - ✓ API call successful. Remaining today: 7422
# 2025-11-23 18:26:41,184 - INFO - ✓ API call successful. Remaining today: 7421
# 2025-11-23 18:26:41,741 - INFO - ✓ API call successful. Remaining today: 7384
# 2025-11-23 18:26:42,249 - INFO - ✓ API call successful. Remaining today: 7383
# 2025-11-23 18:26:42,790 - INFO - ✓ API call successful. Remaining today: 7382
# 2025-11-23 18:26:43,304 - INFO - ✓ API call successful. Remaining today: 7381
# 2025-11-23 18:26:43,827 - INFO - ✓ API call successful. Remaining today: 7380
# 2025-11-23 18:26:44,347 - INFO - ✓ API call successful. Remaining today: 7379
# 2025-11-23 18:26:44,858 - INFO - ✓ API call successful. Remaining today: 7378
# 2025-11-23 18:26:45,356 - INFO - ✓ API call successful. Remaining today: 7377
# 2025-11-23 18:26:45,856 - INFO - ✓ API call successful. Remaining today: 7376
# 2025-11-23 18:26:46,412 - INFO - ✓ API call successful. Remaining today: 7375
# 2025-11-23 18:26:46,928 - INFO - ✓ API call successful. Remaining today: 7374
# 2025-11-23 18:26:47,458 - INFO - ✓ API call successful. Remaining today: 7373
# 2025-11-23 18:26:47,982 - INFO - ✓ API call successful. Remaining today: 7372
# 2025-11-23 18:26:48,492 - INFO - ✓ API call successful. Remaining today: 7371
# 2025-11-23 18:26:49,032 - INFO - ✓ API call successful. Remaining today: 7370
# 2025-11-23 18:26:49,536 - INFO - ✓ API call successful. Remaining today: 7369
# 2025-11-23 18:26:50,070 - INFO - ✓ API call successful. Remaining today: 7368
# 2025-11-23 18:26:50,575 - INFO - ✓ API call successful. Remaining today: 7367
# 2025-11-23 18:26:51,091 - INFO - ✓ API call successful. Remaining today: 7366
# 2025-11-23 18:26:51,596 - INFO - ✓ API call successful. Remaining today: 7365
# 2025-11-23 18:26:52,106 - INFO - ✓ API call successful. Remaining today: 7364
# 2025-11-23 18:26:52,616 - INFO - ✓ API call successful. Remaining today: 7363
# 2025-11-23 18:26:53,133 - INFO - ✓ API call successful. Remaining today: 7362
# 2025-11-23 18:26:53,647 - INFO - ✓ API call successful. Remaining today: 7361
# 2025-11-23 18:26:54,160 - INFO - ✓ API call successful. Remaining today: 7360
# 2025-11-23 18:26:54,679 - INFO - ✓ API call successful. Remaining today: 7359
# 2025-11-23 18:26:55,178 - INFO - ✓ API call successful. Remaining today: 7358
# 2025-11-23 18:26:55,680 - INFO - ✓ API call successful. Remaining today: 7357
# 2025-11-23 18:26:56,183 - INFO - ✓ API call successful. Remaining today: 7356
# 2025-11-23 18:26:56,688 - INFO - ✓ API call successful. Remaining today: 7355
# 2025-11-23 18:26:57,202 - INFO - ✓ API call successful. Remaining today: 7354
# 2025-11-23 18:26:57,708 - INFO - ✓ API call successful. Remaining today: 7353
# 2025-11-23 18:26:58,214 - INFO - ✓ API call successful. Remaining today: 7352
# 2025-11-23 18:26:58,724 - INFO - ✓ API call successful. Remaining today: 7351
# 2025-11-23 18:26:59,232 - INFO - ✓ API call successful. Remaining today: 7350
# 2025-11-23 18:26:59,735 - INFO - ✓ API call successful. Remaining today: 7349
# 2025-11-23 18:26:59,738 - INFO - Progress: 150/1221 games (12.3%) | Speed: 1.9 games/sec | ETA: 9.3 min
# 2025-11-23 18:27:00,261 - INFO - ✓ API call successful. Remaining today: 7348
# 2025-11-23 18:27:00,769 - INFO - ✓ API call successful. Remaining today: 7463
# 2025-11-23 18:27:01,287 - INFO - ✓ API call successful. Remaining today: 7462
# 2025-11-23 18:27:01,821 - INFO - ✓ API call successful. Remaining today: 7461
# 2025-11-23 18:27:02,350 - INFO - ✓ API call successful. Remaining today: 7460
# 2025-11-23 18:27:02,866 - INFO - ✓ API call successful. Remaining today: 7459
# 2025-11-23 18:27:03,367 - INFO - ✓ API call successful. Remaining today: 7458
# 2025-11-23 18:27:03,881 - INFO - ✓ API call successful. Remaining today: 7457
# 2025-11-23 18:27:04,395 - INFO - ✓ API call successful. Remaining today: 7456
# 2025-11-23 18:27:04,912 - INFO - ✓ API call successful. Remaining today: 7455
# 2025-11-23 18:27:05,422 - INFO - ✓ API call successful. Remaining today: 7454
# 2025-11-23 18:27:05,939 - INFO - ✓ API call successful. Remaining today: 7453
# 2025-11-23 18:27:06,453 - INFO - ✓ API call successful. Remaining today: 7452
# 2025-11-23 18:27:06,970 - INFO - ✓ API call successful. Remaining today: 7451
# 2025-11-23 18:27:07,491 - INFO - ✓ API call successful. Remaining today: 7450
# 2025-11-23 18:27:08,008 - INFO - ✓ API call successful. Remaining today: 7449
# 2025-11-23 18:27:08,520 - INFO - ✓ API call successful. Remaining today: 7448
# 2025-11-23 18:27:09,021 - INFO - ✓ API call successful. Remaining today: 7447
# 2025-11-23 18:27:09,533 - INFO - ✓ API call successful. Remaining today: 7446
# 2025-11-23 18:27:10,049 - INFO - ✓ API call successful. Remaining today: 7445
# 2025-11-23 18:27:10,564 - INFO - ✓ API call successful. Remaining today: 7444
# 2025-11-23 18:27:11,067 - INFO - ✓ API call successful. Remaining today: 7443
# 2025-11-23 18:27:11,560 - INFO - ✓ API call successful. Remaining today: 7442
# 2025-11-23 18:27:12,109 - INFO - ✓ API call successful. Remaining today: 7441
# 2025-11-23 18:27:12,615 - INFO - ✓ API call successful. Remaining today: 7440
# 2025-11-23 18:27:13,122 - INFO - ✓ API call successful. Remaining today: 7439
# 2025-11-23 18:27:13,630 - INFO - ✓ API call successful. Remaining today: 7438
# 2025-11-23 18:27:14,214 - INFO - ✓ API call successful. Remaining today: 7437
# 2025-11-23 18:27:14,755 - INFO - ✓ API call successful. Remaining today: 7436
# 2025-11-23 18:27:15,261 - INFO - ✓ API call successful. Remaining today: 7435
# 2025-11-23 18:27:15,775 - INFO - ✓ API call successful. Remaining today: 7434
# 2025-11-23 18:27:16,284 - INFO - ✓ API call successful. Remaining today: 7433
# 2025-11-23 18:27:16,795 - INFO - ✓ API call successful. Remaining today: 7432
# 2025-11-23 18:27:17,306 - INFO - ✓ API call successful. Remaining today: 7431
# 2025-11-23 18:27:17,900 - INFO - ✓ API call successful. Remaining today: 7430
# 2025-11-23 18:27:18,416 - INFO - ✓ API call successful. Remaining today: 7429
# 2025-11-23 18:27:18,926 - INFO - ✓ API call successful. Remaining today: 7428
# 2025-11-23 18:27:19,437 - INFO - ✓ API call successful. Remaining today: 7427
# 2025-11-23 18:27:19,956 - INFO - ✓ API call successful. Remaining today: 7426
# 2025-11-23 18:27:20,462 - INFO - ✓ API call successful. Remaining today: 7425
# 2025-11-23 18:27:20,966 - INFO - ✓ API call successful. Remaining today: 7424
# 2025-11-23 18:27:21,484 - INFO - ✓ API call successful. Remaining today: 7423
# 2025-11-23 18:27:21,995 - INFO - ✓ API call successful. Remaining today: 7422
# 2025-11-23 18:27:22,500 - INFO - ✓ API call successful. Remaining today: 7421
# 2025-11-23 18:27:23,017 - INFO - ✓ API call successful. Remaining today: 7420
# 2025-11-23 18:27:23,521 - INFO - ✓ API call successful. Remaining today: 7419
# 2025-11-23 18:27:24,021 - INFO - ✓ API call successful. Remaining today: 7418
# 2025-11-23 18:27:24,536 - INFO - ✓ API call successful. Remaining today: 7417
# 2025-11-23 18:27:25,039 - INFO - ✓ API call successful. Remaining today: 7416
# 2025-11-23 18:27:25,548 - INFO - ✓ API call successful. Remaining today: 7415
# 2025-11-23 18:27:25,550 - INFO - Progress: 200/1221 games (16.4%) | Speed: 1.9 games/sec | ETA: 8.8 min
# 2025-11-23 18:27:26,047 - INFO - ✓ API call successful. Remaining today: 7414
# 2025-11-23 18:27:26,553 - INFO - ✓ API call successful. Remaining today: 7413
# 2025-11-23 18:27:27,061 - INFO - ✓ API call successful. Remaining today: 7412
# 2025-11-23 18:27:27,566 - INFO - ✓ API call successful. Remaining today: 7411
# 2025-11-23 18:27:28,079 - INFO - ✓ API call successful. Remaining today: 7410
# 2025-11-23 18:27:28,583 - INFO - ✓ API call successful. Remaining today: 7409
# 2025-11-23 18:27:29,092 - INFO - ✓ API call successful. Remaining today: 7408
# 2025-11-23 18:27:29,599 - INFO - ✓ API call successful. Remaining today: 7407
# 2025-11-23 18:27:30,118 - INFO - ✓ API call successful. Remaining today: 7406
# 2025-11-23 18:27:30,649 - INFO - ✓ API call successful. Remaining today: 7405
# 2025-11-23 18:27:31,167 - INFO - ✓ API call successful. Remaining today: 7404
# 2025-11-23 18:27:31,672 - INFO - ✓ API call successful. Remaining today: 7403
# 2025-11-23 18:27:32,191 - INFO - ✓ API call successful. Remaining today: 7402
# 2025-11-23 18:27:32,695 - INFO - ✓ API call successful. Remaining today: 7401
# 2025-11-23 18:27:33,203 - INFO - ✓ API call successful. Remaining today: 7400
# 2025-11-23 18:27:33,713 - INFO - ✓ API call successful. Remaining today: 7399
# 2025-11-23 18:27:34,229 - INFO - ✓ API call successful. Remaining today: 7398
# 2025-11-23 18:27:34,738 - INFO - ✓ API call successful. Remaining today: 7397
# 2025-11-23 18:27:35,245 - INFO - ✓ API call successful. Remaining today: 7396
# 2025-11-23 18:27:35,754 - INFO - ✓ API call successful. Remaining today: 7395
# 2025-11-23 18:27:36,334 - INFO - ✓ API call successful. Remaining today: 7394
# 2025-11-23 18:27:36,848 - INFO - ✓ API call successful. Remaining today: 7393
# 2025-11-23 18:27:37,362 - INFO - ✓ API call successful. Remaining today: 7392
# 2025-11-23 18:27:37,971 - INFO - ✓ API call successful. Remaining today: 7391
# 2025-11-23 18:27:38,487 - INFO - ✓ API call successful. Remaining today: 7390
# 2025-11-23 18:27:38,988 - INFO - ✓ API call successful. Remaining today: 7389
# 2025-11-23 18:27:39,496 - INFO - ✓ API call successful. Remaining today: 7388
# 2025-11-23 18:27:39,994 - INFO - ✓ API call successful. Remaining today: 7387
# 2025-11-23 18:27:40,491 - INFO - ✓ API call successful. Remaining today: 7386
# 2025-11-23 18:27:41,002 - INFO - ✓ API call successful. Remaining today: 7385
# 2025-11-23 18:27:41,509 - INFO - ✓ API call successful. Remaining today: 7384
# 2025-11-23 18:27:42,087 - INFO - ✓ API call successful. Remaining today: 7267
# 2025-11-23 18:27:42,596 - INFO - ✓ API call successful. Remaining today: 7266
# 2025-11-23 18:27:43,115 - INFO - ✓ API call successful. Remaining today: 7265
# 2025-11-23 18:27:43,625 - INFO - ✓ API call successful. Remaining today: 7264
# 2025-11-23 18:27:44,134 - INFO - ✓ API call successful. Remaining today: 7263
# 2025-11-23 18:27:44,682 - INFO - ✓ API call successful. Remaining today: 7262
# 2025-11-23 18:27:45,188 - INFO - ✓ API call successful. Remaining today: 7261
# 2025-11-23 18:27:45,710 - INFO - ✓ API call successful. Remaining today: 7260
# 2025-11-23 18:27:46,218 - INFO - ✓ API call successful. Remaining today: 7259
# 2025-11-23 18:27:46,764 - INFO - ✓ API call successful. Remaining today: 7258
# 2025-11-23 18:27:47,275 - INFO - ✓ API call successful. Remaining today: 7257
# 2025-11-23 18:27:47,792 - INFO - ✓ API call successful. Remaining today: 7256
# 2025-11-23 18:27:48,308 - INFO - ✓ API call successful. Remaining today: 7255
# 2025-11-23 18:27:48,814 - INFO - ✓ API call successful. Remaining today: 7254
# 2025-11-23 18:27:49,325 - INFO - ✓ API call successful. Remaining today: 7253
# 2025-11-23 18:27:49,841 - INFO - ✓ API call successful. Remaining today: 7252
# 2025-11-23 18:27:50,341 - INFO - ✓ API call successful. Remaining today: 7251
# 2025-11-23 18:27:50,854 - INFO - ✓ API call successful. Remaining today: 7250
# 2025-11-23 18:27:51,392 - INFO - ✓ API call successful. Remaining today: 7249
# 2025-11-23 18:27:51,395 - INFO - Progress: 250/1221 games (20.5%) | Speed: 1.9 games/sec | ETA: 8.4 min
# 2025-11-23 18:27:51,915 - INFO - ✓ API call successful. Remaining today: 7248
# 2025-11-23 18:27:52,434 - INFO - ✓ API call successful. Remaining today: 7247
# 2025-11-23 18:27:52,941 - INFO - ✓ API call successful. Remaining today: 7246
# 2025-11-23 18:27:53,444 - INFO - ✓ API call successful. Remaining today: 7245
# 2025-11-23 18:27:53,944 - INFO - ✓ API call successful. Remaining today: 7244
# 2025-11-23 18:27:54,458 - INFO - ✓ API call successful. Remaining today: 7243
# 2025-11-23 18:27:54,975 - INFO - ✓ API call successful. Remaining today: 7242
# 2025-11-23 18:27:55,480 - INFO - ✓ API call successful. Remaining today: 7241
# 2025-11-23 18:27:56,001 - INFO - ✓ API call successful. Remaining today: 7240
# 2025-11-23 18:27:56,511 - INFO - ✓ API call successful. Remaining today: 7239
# 2025-11-23 18:27:57,023 - INFO - ✓ API call successful. Remaining today: 7238
# 2025-11-23 18:27:57,534 - INFO - ✓ API call successful. Remaining today: 7237
# 2025-11-23 18:27:58,042 - INFO - ✓ API call successful. Remaining today: 7236
# 2025-11-23 18:27:58,553 - INFO - ✓ API call successful. Remaining today: 7235
# 2025-11-23 18:27:59,068 - INFO - ✓ API call successful. Remaining today: 7234
# 2025-11-23 18:27:59,581 - INFO - ✓ API call successful. Remaining today: 7233
# 2025-11-23 18:28:00,101 - INFO - ✓ API call successful. Remaining today: 7232
# 2025-11-23 18:28:00,700 - INFO - ✓ API call successful. Remaining today: 7347
# 2025-11-23 18:28:01,217 - INFO - ✓ API call successful. Remaining today: 7346
# 2025-11-23 18:28:01,730 - INFO - ✓ API call successful. Remaining today: 7345
# 2025-11-23 18:28:02,252 - INFO - ✓ API call successful. Remaining today: 7344
# 2025-11-23 18:28:02,769 - INFO - ✓ API call successful. Remaining today: 7343
# 2025-11-23 18:28:03,299 - INFO - ✓ API call successful. Remaining today: 7342
# 2025-11-23 18:28:03,792 - INFO - ✓ API call successful. Remaining today: 7341
# 2025-11-23 18:28:04,301 - INFO - ✓ API call successful. Remaining today: 7340
# 2025-11-23 18:28:04,809 - INFO - ✓ API call successful. Remaining today: 7339
# 2025-11-23 18:28:05,313 - INFO - ✓ API call successful. Remaining today: 7338
# 2025-11-23 18:28:05,817 - INFO - ✓ API call successful. Remaining today: 7337
# 2025-11-23 18:28:06,327 - INFO - ✓ API call successful. Remaining today: 7336
# 2025-11-23 18:28:06,859 - INFO - ✓ API call successful. Remaining today: 7335
# 2025-11-23 18:28:07,369 - INFO - ✓ API call successful. Remaining today: 7334
# 2025-11-23 18:28:07,884 - INFO - ✓ API call successful. Remaining today: 7333
# 2025-11-23 18:28:08,387 - INFO - ✓ API call successful. Remaining today: 7332
# 2025-11-23 18:28:08,894 - INFO - ✓ API call successful. Remaining today: 7331
# 2025-11-23 18:28:09,413 - INFO - ✓ API call successful. Remaining today: 7330
# 2025-11-23 18:28:09,926 - INFO - ✓ API call successful. Remaining today: 7329
# 2025-11-23 18:28:10,446 - INFO - ✓ API call successful. Remaining today: 7328
# 2025-11-23 18:28:10,952 - INFO - ✓ API call successful. Remaining today: 7327
# 2025-11-23 18:28:11,467 - INFO - ✓ API call successful. Remaining today: 7326
# 2025-11-23 18:28:11,971 - INFO - ✓ API call successful. Remaining today: 7325
# 2025-11-23 18:28:12,482 - INFO - ✓ API call successful. Remaining today: 7324
# 2025-11-23 18:28:13,034 - INFO - ✓ API call successful. Remaining today: 7323
# 2025-11-23 18:28:13,560 - INFO - ✓ API call successful. Remaining today: 7322
# 2025-11-23 18:28:14,069 - INFO - ✓ API call successful. Remaining today: 7321
# 2025-11-23 18:28:14,591 - INFO - ✓ API call successful. Remaining today: 7320
# 2025-11-23 18:28:15,108 - INFO - ✓ API call successful. Remaining today: 7319
# 2025-11-23 18:28:15,625 - INFO - ✓ API call successful. Remaining today: 7318
# 2025-11-23 18:28:16,134 - INFO - ✓ API call successful. Remaining today: 7317
# 2025-11-23 18:28:16,657 - INFO - ✓ API call successful. Remaining today: 7316
# 2025-11-23 18:28:17,167 - INFO - ✓ API call successful. Remaining today: 7315
# 2025-11-23 18:28:17,169 - INFO - Progress: 300/1221 games (24.6%) | Speed: 1.9 games/sec | ETA: 7.9 min
# 2025-11-23 18:28:17,683 - INFO - ✓ API call successful. Remaining today: 7314
# 2025-11-23 18:28:18,185 - INFO - ✓ API call successful. Remaining today: 7313
# 2025-11-23 18:28:18,711 - INFO - ✓ API call successful. Remaining today: 7312
# 2025-11-23 18:28:19,339 - INFO - ✓ API call successful. Remaining today: 7311
# 2025-11-23 18:28:19,856 - INFO - ✓ API call successful. Remaining today: 7310
# 2025-11-23 18:28:20,370 - INFO - ✓ API call successful. Remaining today: 7309
# 2025-11-23 18:28:20,975 - INFO - ✓ API call successful. Remaining today: 7308
# 2025-11-23 18:28:21,478 - INFO - ✓ API call successful. Remaining today: 7307
# 2025-11-23 18:28:21,993 - INFO - ✓ API call successful. Remaining today: 7306
# 2025-11-23 18:28:22,510 - INFO - ✓ API call successful. Remaining today: 7305
# 2025-11-23 18:28:23,016 - INFO - ✓ API call successful. Remaining today: 7304
# 2025-11-23 18:28:23,521 - INFO - ✓ API call successful. Remaining today: 7303
# 2025-11-23 18:28:24,032 - INFO - ✓ API call successful. Remaining today: 7302
# 2025-11-23 18:28:24,546 - INFO - ✓ API call successful. Remaining today: 7301
# 2025-11-23 18:28:25,052 - INFO - ✓ API call successful. Remaining today: 7300
# 2025-11-23 18:28:25,569 - INFO - ✓ API call successful. Remaining today: 7299
# 2025-11-23 18:28:26,100 - INFO - ✓ API call successful. Remaining today: 7298
# 2025-11-23 18:28:26,611 - INFO - ✓ API call successful. Remaining today: 7297
# 2025-11-23 18:28:27,118 - INFO - ✓ API call successful. Remaining today: 7296
# 2025-11-23 18:28:27,617 - INFO - ✓ API call successful. Remaining today: 7295
# 2025-11-23 18:28:28,116 - INFO - ✓ API call successful. Remaining today: 7294
# 2025-11-23 18:28:28,624 - INFO - ✓ API call successful. Remaining today: 7293
# 2025-11-23 18:28:29,132 - INFO - ✓ API call successful. Remaining today: 7292
# 2025-11-23 18:28:29,634 - INFO - ✓ API call successful. Remaining today: 7291
# 2025-11-23 18:28:30,135 - INFO - ✓ API call successful. Remaining today: 7290
# 2025-11-23 18:28:30,646 - INFO - ✓ API call successful. Remaining today: 7289
# 2025-11-23 18:28:31,150 - INFO - ✓ API call successful. Remaining today: 7288
# 2025-11-23 18:28:31,652 - INFO - ✓ API call successful. Remaining today: 7287
# 2025-11-23 18:28:32,152 - INFO - ✓ API call successful. Remaining today: 7286
# 2025-11-23 18:28:32,667 - INFO - ✓ API call successful. Remaining today: 7285
# 2025-11-23 18:28:33,239 - INFO - ✓ API call successful. Remaining today: 7284
# 2025-11-23 18:28:33,734 - INFO - ✓ API call successful. Remaining today: 7283
# 2025-11-23 18:28:34,242 - INFO - ✓ API call successful. Remaining today: 7282
# 2025-11-23 18:28:34,756 - INFO - ✓ API call successful. Remaining today: 7281
# 2025-11-23 18:28:35,256 - INFO - ✓ API call successful. Remaining today: 7280
# 2025-11-23 18:28:35,766 - INFO - ✓ API call successful. Remaining today: 7279
# 2025-11-23 18:28:36,282 - INFO - ✓ API call successful. Remaining today: 7278
# 2025-11-23 18:28:36,787 - INFO - ✓ API call successful. Remaining today: 7277
# 2025-11-23 18:28:37,293 - INFO - ✓ API call successful. Remaining today: 7276
# 2025-11-23 18:28:37,879 - INFO - ✓ API call successful. Remaining today: 7275
# 2025-11-23 18:28:38,378 - INFO - ✓ API call successful. Remaining today: 7274
# 2025-11-23 18:28:38,891 - INFO - ✓ API call successful. Remaining today: 7273
# 2025-11-23 18:28:39,401 - INFO - ✓ API call successful. Remaining today: 7272
# 2025-11-23 18:28:39,905 - INFO - ✓ API call successful. Remaining today: 7271
# 2025-11-23 18:28:40,424 - INFO - ✓ API call successful. Remaining today: 7270
# 2025-11-23 18:28:40,929 - INFO - ✓ API call successful. Remaining today: 7269
# 2025-11-23 18:28:41,448 - INFO - ✓ API call successful. Remaining today: 7268
# 2025-11-23 18:28:41,961 - INFO - ✓ API call successful. Remaining today: 7267
# 2025-11-23 18:28:42,513 - INFO - ✓ API call successful. Remaining today: 7150
# 2025-11-23 18:28:43,019 - INFO - ✓ API call successful. Remaining today: 7149
# 2025-11-23 18:28:43,022 - INFO - Progress: 350/1221 games (28.7%) | Speed: 1.9 games/sec | ETA: 7.5 min
# 2025-11-23 18:28:43,539 - INFO - ✓ API call successful. Remaining today: 7148
# 2025-11-23 18:28:44,047 - INFO - ✓ API call successful. Remaining today: 7147
# 2025-11-23 18:28:44,560 - INFO - ✓ API call successful. Remaining today: 7146
# 2025-11-23 18:28:46,066 - INFO - ✓ API call successful. Remaining today: 7145
# 2025-11-23 18:28:46,591 - INFO - ✓ API call successful. Remaining today: 7144
# 2025-11-23 18:28:47,114 - INFO - ✓ API call successful. Remaining today: 7143
# 2025-11-23 18:28:47,626 - INFO - ✓ API call successful. Remaining today: 7142
# 2025-11-23 18:28:48,216 - INFO - ✓ API call successful. Remaining today: 7141
# 2025-11-23 18:28:48,717 - INFO - ✓ API call successful. Remaining today: 7140
# 2025-11-23 18:28:49,241 - INFO - ✓ API call successful. Remaining today: 7139
# 2025-11-23 18:28:49,745 - INFO - ✓ API call successful. Remaining today: 7138
# 2025-11-23 18:28:50,270 - INFO - ✓ API call successful. Remaining today: 7137
# 2025-11-23 18:28:50,784 - INFO - ✓ API call successful. Remaining today: 7136
# 2025-11-23 18:28:51,395 - INFO - ✓ API call successful. Remaining today: 7135
# 2025-11-23 18:28:51,899 - INFO - ✓ API call successful. Remaining today: 7134
# 2025-11-23 18:28:52,509 - INFO - ✓ API call successful. Remaining today: 7133
# 2025-11-23 18:28:53,045 - INFO - ✓ API call successful. Remaining today: 7132
# 2025-11-23 18:28:53,560 - INFO - ✓ API call successful. Remaining today: 7131
# 2025-11-23 18:28:54,090 - INFO - ✓ API call successful. Remaining today: 7130
# 2025-11-23 18:28:54,598 - INFO - ✓ API call successful. Remaining today: 7129
# 2025-11-23 18:28:55,112 - INFO - ✓ API call successful. Remaining today: 7128
# 2025-11-23 18:28:55,636 - INFO - ✓ API call successful. Remaining today: 7127
# 2025-11-23 18:28:56,140 - INFO - ✓ API call successful. Remaining today: 7126
# 2025-11-23 18:28:56,647 - INFO - ✓ API call successful. Remaining today: 7125
# 2025-11-23 18:28:57,177 - INFO - ✓ API call successful. Remaining today: 7124
# 2025-11-23 18:28:57,693 - INFO - ✓ API call successful. Remaining today: 7123
# 2025-11-23 18:28:58,203 - INFO - ✓ API call successful. Remaining today: 7122
# 2025-11-23 18:28:58,714 - INFO - ✓ API call successful. Remaining today: 7121
# 2025-11-23 18:28:59,228 - INFO - ✓ API call successful. Remaining today: 7120
# 2025-11-23 18:28:59,744 - INFO - ✓ API call successful. Remaining today: 7119
# 2025-11-23 18:29:00,244 - INFO - ✓ API call successful. Remaining today: 7118
# 2025-11-23 18:29:00,745 - INFO - ✓ API call successful. Remaining today: 7231
# 2025-11-23 18:29:01,257 - INFO - ✓ API call successful. Remaining today: 7230
# 2025-11-23 18:29:01,771 - INFO - ✓ API call successful. Remaining today: 7229
# 2025-11-23 18:29:02,284 - INFO - ✓ API call successful. Remaining today: 7228
# 2025-11-23 18:29:02,802 - INFO - ✓ API call successful. Remaining today: 7227
# 2025-11-23 18:29:03,309 - INFO - ✓ API call successful. Remaining today: 7226
# 2025-11-23 18:29:03,891 - INFO - ✓ API call successful. Remaining today: 7225
# 2025-11-23 18:29:04,406 - INFO - ✓ API call successful. Remaining today: 7224
# 2025-11-23 18:29:04,918 - INFO - ✓ API call successful. Remaining today: 7223
# 2025-11-23 18:29:05,434 - INFO - ✓ API call successful. Remaining today: 7222
# 2025-11-23 18:29:05,949 - INFO - ✓ API call successful. Remaining today: 7221
# 2025-11-23 18:29:06,461 - INFO - ✓ API call successful. Remaining today: 7220
# 2025-11-23 18:29:06,981 - INFO - ✓ API call successful. Remaining today: 7219
# 2025-11-23 18:29:07,499 - INFO - ✓ API call successful. Remaining today: 7218
# 2025-11-23 18:29:08,008 - INFO - ✓ API call successful. Remaining today: 7217
# 2025-11-23 18:29:08,517 - INFO - ✓ API call successful. Remaining today: 7216
# 2025-11-23 18:29:09,032 - INFO - ✓ API call successful. Remaining today: 7215
# 2025-11-23 18:29:09,539 - INFO - ✓ API call successful. Remaining today: 7214
# 2025-11-23 18:29:10,049 - INFO - ✓ API call successful. Remaining today: 7213
# 2025-11-23 18:29:10,052 - INFO - Progress: 400/1221 games (32.8%) | Speed: 1.9 games/sec | ETA: 7.1 min
# 2025-11-23 18:29:10,567 - INFO - ✓ API call successful. Remaining today: 7212
# 2025-11-23 18:29:11,090 - INFO - ✓ API call successful. Remaining today: 7211
# 2025-11-23 18:29:11,602 - INFO - ✓ API call successful. Remaining today: 7210
# 2025-11-23 18:29:12,107 - INFO - ✓ API call successful. Remaining today: 7209
# 2025-11-23 18:29:12,611 - INFO - ✓ API call successful. Remaining today: 7208
# 2025-11-23 18:29:13,112 - INFO - ✓ API call successful. Remaining today: 7207
# 2025-11-23 18:29:13,612 - INFO - ✓ API call successful. Remaining today: 7206
# 2025-11-23 18:29:14,126 - INFO - ✓ API call successful. Remaining today: 7205
# 2025-11-23 18:29:14,636 - INFO - ✓ API call successful. Remaining today: 7204
# 2025-11-23 18:29:15,145 - INFO - ✓ API call successful. Remaining today: 7203
# 2025-11-23 18:29:15,654 - INFO - ✓ API call successful. Remaining today: 7202
# 2025-11-23 18:29:16,169 - INFO - ✓ API call successful. Remaining today: 7201
# 2025-11-23 18:29:16,679 - INFO - ✓ API call successful. Remaining today: 7200
# 2025-11-23 18:29:17,189 - INFO - ✓ API call successful. Remaining today: 7199
# 2025-11-23 18:29:17,706 - INFO - ✓ API call successful. Remaining today: 7198
# 2025-11-23 18:29:18,213 - INFO - ✓ API call successful. Remaining today: 7197
# 2025-11-23 18:29:18,726 - INFO - ✓ API call successful. Remaining today: 7196
# 2025-11-23 18:29:19,235 - INFO - ✓ API call successful. Remaining today: 7195
# 2025-11-23 18:29:19,741 - INFO - ✓ API call successful. Remaining today: 7194
# 2025-11-23 18:29:20,249 - INFO - ✓ API call successful. Remaining today: 7193
# 2025-11-23 18:29:20,762 - INFO - ✓ API call successful. Remaining today: 7192
# 2025-11-23 18:29:21,300 - INFO - ✓ API call successful. Remaining today: 7191
# 2025-11-23 18:29:21,809 - INFO - ✓ API call successful. Remaining today: 7190
# 2025-11-23 18:29:22,322 - INFO - ✓ API call successful. Remaining today: 7189
# 2025-11-23 18:29:22,837 - INFO - ✓ API call successful. Remaining today: 7188
# 2025-11-23 18:29:23,341 - INFO - ✓ API call successful. Remaining today: 7187
# 2025-11-23 18:29:23,852 - INFO - ✓ API call successful. Remaining today: 7186
# 2025-11-23 18:29:24,383 - INFO - ✓ API call successful. Remaining today: 7185
# 2025-11-23 18:29:24,892 - INFO - ✓ API call successful. Remaining today: 7184
# 2025-11-23 18:29:25,404 - INFO - ✓ API call successful. Remaining today: 7183
# 2025-11-23 18:29:25,930 - INFO - ✓ API call successful. Remaining today: 7182
# 2025-11-23 18:29:26,445 - INFO - ✓ API call successful. Remaining today: 7181
# 2025-11-23 18:29:26,956 - INFO - ✓ API call successful. Remaining today: 7180
# 2025-11-23 18:29:27,467 - INFO - ✓ API call successful. Remaining today: 7179
# 2025-11-23 18:29:27,970 - INFO - ✓ API call successful. Remaining today: 7178
# 2025-11-23 18:29:28,482 - INFO - ✓ API call successful. Remaining today: 7177
# 2025-11-23 18:29:28,989 - INFO - ✓ API call successful. Remaining today: 7176
# 2025-11-23 18:29:29,502 - INFO - ✓ API call successful. Remaining today: 7175
# 2025-11-23 18:29:30,009 - INFO - ✓ API call successful. Remaining today: 7174
# 2025-11-23 18:29:30,529 - INFO - ✓ API call successful. Remaining today: 7173
# 2025-11-23 18:29:31,038 - INFO - ✓ API call successful. Remaining today: 7172
# 2025-11-23 18:29:31,557 - INFO - ✓ API call successful. Remaining today: 7171
# 2025-11-23 18:29:32,064 - INFO - ✓ API call successful. Remaining today: 7170
# 2025-11-23 18:29:32,571 - INFO - ✓ API call successful. Remaining today: 7169
# 2025-11-23 18:29:33,074 - INFO - ✓ API call successful. Remaining today: 7168
# 2025-11-23 18:29:33,575 - INFO - ✓ API call successful. Remaining today: 7167
# 2025-11-23 18:29:34,087 - INFO - ✓ API call successful. Remaining today: 7166
# 2025-11-23 18:29:34,629 - INFO - ✓ API call successful. Remaining today: 7165
# 2025-11-23 18:29:35,135 - INFO - ✓ API call successful. Remaining today: 7164
# 2025-11-23 18:29:35,653 - INFO - ✓ API call successful. Remaining today: 7163
# 2025-11-23 18:29:35,656 - INFO - Progress: 450/1221 games (36.9%) | Speed: 1.9 games/sec | ETA: 6.7 min
# 2025-11-23 18:29:36,166 - INFO - ✓ API call successful. Remaining today: 7162
# 2025-11-23 18:29:36,686 - INFO - ✓ API call successful. Remaining today: 7161
# 2025-11-23 18:29:37,271 - INFO - ✓ API call successful. Remaining today: 7160
# 2025-11-23 18:29:37,784 - INFO - ✓ API call successful. Remaining today: 7159
# 2025-11-23 18:29:38,302 - INFO - ✓ API call successful. Remaining today: 7158
# 2025-11-23 18:29:38,825 - INFO - ✓ API call successful. Remaining today: 7157
# 2025-11-23 18:29:39,334 - INFO - ✓ API call successful. Remaining today: 7156
# 2025-11-23 18:29:39,834 - INFO - ✓ API call successful. Remaining today: 7155
# 2025-11-23 18:29:40,347 - INFO - ✓ API call successful. Remaining today: 7154
# 2025-11-23 18:29:40,859 - INFO - ✓ API call successful. Remaining today: 7153
# 2025-11-23 18:29:41,366 - INFO - ✓ API call successful. Remaining today: 7152
# 2025-11-23 18:29:41,878 - INFO - ✓ API call successful. Remaining today: 7151
# 2025-11-23 18:29:42,381 - INFO - ✓ API call successful. Remaining today: 7150
# 2025-11-23 18:29:42,936 - INFO - ✓ API call successful. Remaining today: 7035
# 2025-11-23 18:29:43,440 - INFO - ✓ API call successful. Remaining today: 7034
# 2025-11-23 18:29:43,949 - INFO - ✓ API call successful. Remaining today: 7033
# 2025-11-23 18:29:44,466 - INFO - ✓ API call successful. Remaining today: 7032
# 2025-11-23 18:29:44,978 - INFO - ✓ API call successful. Remaining today: 7031
# 2025-11-23 18:29:45,494 - INFO - ✓ API call successful. Remaining today: 7030
# 2025-11-23 18:29:46,016 - INFO - ✓ API call successful. Remaining today: 7029
# 2025-11-23 18:29:46,528 - INFO - ✓ API call successful. Remaining today: 7028
# 2025-11-23 18:29:47,042 - INFO - ✓ API call successful. Remaining today: 7027
# 2025-11-23 18:29:47,557 - INFO - ✓ API call successful. Remaining today: 7026
# 2025-11-23 18:29:48,052 - INFO - ✓ API call successful. Remaining today: 7025
# 2025-11-23 18:29:48,563 - INFO - ✓ API call successful. Remaining today: 7024
# 2025-11-23 18:29:49,069 - INFO - ✓ API call successful. Remaining today: 7023
# 2025-11-23 18:29:49,584 - INFO - ✓ API call successful. Remaining today: 7022
# 2025-11-23 18:29:50,089 - INFO - ✓ API call successful. Remaining today: 7021
# 2025-11-23 18:29:50,604 - INFO - ✓ API call successful. Remaining today: 7020
# 2025-11-23 18:29:51,109 - INFO - ✓ API call successful. Remaining today: 7019
# 2025-11-23 18:29:51,666 - INFO - ✓ API call successful. Remaining today: 7018
# 2025-11-23 18:29:52,230 - INFO - ✓ API call successful. Remaining today: 7017
# 2025-11-23 18:29:52,888 - INFO - ✓ API call successful. Remaining today: 7016
# 2025-11-23 18:29:53,409 - INFO - ✓ API call successful. Remaining today: 7015
# 2025-11-23 18:29:53,920 - INFO - ✓ API call successful. Remaining today: 7014
# 2025-11-23 18:29:54,425 - INFO - ✓ API call successful. Remaining today: 7013
# 2025-11-23 18:29:54,941 - INFO - ✓ API call successful. Remaining today: 7012
# 2025-11-23 18:29:55,456 - INFO - ✓ API call successful. Remaining today: 7011
# 2025-11-23 18:29:55,969 - INFO - ✓ API call successful. Remaining today: 7010
# 2025-11-23 18:29:56,482 - INFO - ✓ API call successful. Remaining today: 7009
# 2025-11-23 18:29:57,023 - INFO - ✓ API call successful. Remaining today: 7008
# 2025-11-23 18:29:57,540 - INFO - ✓ API call successful. Remaining today: 7007
# 2025-11-23 18:29:58,050 - INFO - ✓ API call successful. Remaining today: 7006
# 2025-11-23 18:29:58,554 - INFO - ✓ API call successful. Remaining today: 7005
# 2025-11-23 18:29:59,066 - INFO - ✓ API call successful. Remaining today: 7004
# 2025-11-23 18:29:59,575 - INFO - ✓ API call successful. Remaining today: 7003
# 2025-11-23 18:30:00,084 - INFO - ✓ API call successful. Remaining today: 7002
# 2025-11-23 18:30:00,733 - INFO - ✓ API call successful. Remaining today: 7117
# 2025-11-23 18:30:01,292 - INFO - ✓ API call successful. Remaining today: 7116
# 2025-11-23 18:30:01,850 - INFO - ✓ API call successful. Remaining today: 7115
# 2025-11-23 18:30:01,853 - INFO - Progress: 500/1221 games (41.0%) | Speed: 1.9 games/sec | ETA: 6.2 min
# 2025-11-23 18:30:02,413 - INFO - ✓ API call successful. Remaining today: 7114
# 2025-11-23 18:30:02,930 - INFO - ✓ API call successful. Remaining today: 7113
# 2025-11-23 18:30:03,457 - INFO - ✓ API call successful. Remaining today: 7112
# 2025-11-23 18:30:03,982 - INFO - ✓ API call successful. Remaining today: 7111
# 2025-11-23 18:30:04,507 - INFO - ✓ API call successful. Remaining today: 7110
# 2025-11-23 18:30:05,041 - INFO - ✓ API call successful. Remaining today: 7109
# 2025-11-23 18:30:05,557 - INFO - ✓ API call successful. Remaining today: 7108
# 2025-11-23 18:30:06,075 - INFO - ✓ API call successful. Remaining today: 7107
# 2025-11-23 18:30:06,587 - INFO - ✓ API call successful. Remaining today: 7106
# 2025-11-23 18:30:07,085 - INFO - ✓ API call successful. Remaining today: 7105
# 2025-11-23 18:30:07,600 - INFO - ✓ API call successful. Remaining today: 7104
# 2025-11-23 18:30:08,106 - INFO - ✓ API call successful. Remaining today: 7103
# 2025-11-23 18:30:08,669 - INFO - ✓ API call successful. Remaining today: 7102
# 2025-11-23 18:30:09,184 - INFO - ✓ API call successful. Remaining today: 7101
# 2025-11-23 18:30:09,695 - INFO - ✓ API call successful. Remaining today: 7100
# 2025-11-23 18:30:10,209 - INFO - ✓ API call successful. Remaining today: 7099
# 2025-11-23 18:30:10,736 - INFO - ✓ API call successful. Remaining today: 7098
# 2025-11-23 18:30:11,250 - INFO - ✓ API call successful. Remaining today: 7097
# 2025-11-23 18:30:11,757 - INFO - ✓ API call successful. Remaining today: 7096
# 2025-11-23 18:30:12,287 - INFO - ✓ API call successful. Remaining today: 7095
# 2025-11-23 18:30:12,798 - INFO - ✓ API call successful. Remaining today: 7094
# 2025-11-23 18:30:13,308 - INFO - ✓ API call successful. Remaining today: 7093
# 2025-11-23 18:30:13,823 - INFO - ✓ API call successful. Remaining today: 7092
# 2025-11-23 18:30:14,339 - INFO - ✓ API call successful. Remaining today: 7091
# 2025-11-23 18:30:14,869 - INFO - ✓ API call successful. Remaining today: 7090
# 2025-11-23 18:30:15,396 - INFO - ✓ API call successful. Remaining today: 7089
# 2025-11-23 18:30:15,930 - INFO - ✓ API call successful. Remaining today: 7088
# 2025-11-23 18:30:16,445 - INFO - ✓ API call successful. Remaining today: 7087
# 2025-11-23 18:30:16,952 - INFO - ✓ API call successful. Remaining today: 7086
# 2025-11-23 18:30:17,466 - INFO - ✓ API call successful. Remaining today: 7085
# 2025-11-23 18:30:17,978 - INFO - ✓ API call successful. Remaining today: 7084
# 2025-11-23 18:30:18,496 - INFO - ✓ API call successful. Remaining today: 7083
# 2025-11-23 18:30:18,999 - INFO - ✓ API call successful. Remaining today: 7082
# 2025-11-23 18:30:19,516 - INFO - ✓ API call successful. Remaining today: 7081
# 2025-11-23 18:30:20,032 - INFO - ✓ API call successful. Remaining today: 7080
# 2025-11-23 18:30:20,562 - INFO - ✓ API call successful. Remaining today: 7079
# 2025-11-23 18:30:21,084 - INFO - ✓ API call successful. Remaining today: 7078
# 2025-11-23 18:30:21,591 - INFO - ✓ API call successful. Remaining today: 7077
# 2025-11-23 18:30:22,100 - INFO - ✓ API call successful. Remaining today: 7076
# 2025-11-23 18:30:22,625 - INFO - ✓ API call successful. Remaining today: 7075
# 2025-11-23 18:30:23,135 - INFO - ✓ API call successful. Remaining today: 7074
# 2025-11-23 18:30:23,642 - INFO - ✓ API call successful. Remaining today: 7073
# 2025-11-23 18:30:24,181 - INFO - ✓ API call successful. Remaining today: 7072
# 2025-11-23 18:30:24,681 - INFO - ✓ API call successful. Remaining today: 7071
# 2025-11-23 18:30:25,195 - INFO - ✓ API call successful. Remaining today: 7070
# 2025-11-23 18:30:25,721 - INFO - ✓ API call successful. Remaining today: 7069
# 2025-11-23 18:30:26,234 - INFO - ✓ API call successful. Remaining today: 7068
# 2025-11-23 18:30:26,747 - INFO - ✓ API call successful. Remaining today: 7067
# 2025-11-23 18:30:27,296 - INFO - ✓ API call successful. Remaining today: 7066
# 2025-11-23 18:30:27,804 - INFO - ✓ API call successful. Remaining today: 7065
# 2025-11-23 18:30:27,807 - INFO - Progress: 550/1221 games (45.0%) | Speed: 1.9 games/sec | ETA: 5.8 min
# 2025-11-23 18:30:28,319 - INFO - ✓ API call successful. Remaining today: 7064
# 2025-11-23 18:30:28,835 - INFO - ✓ API call successful. Remaining today: 7063
# 2025-11-23 18:30:29,336 - INFO - ✓ API call successful. Remaining today: 7062
# 2025-11-23 18:30:29,841 - INFO - ✓ API call successful. Remaining today: 7061
# 2025-11-23 18:30:30,349 - INFO - ✓ API call successful. Remaining today: 7060
# 2025-11-23 18:30:30,852 - INFO - ✓ API call successful. Remaining today: 7059
# 2025-11-23 18:30:31,367 - INFO - ✓ API call successful. Remaining today: 7058
# 2025-11-23 18:30:33,725 - INFO - ✓ API call successful. Remaining today: 7057
# 2025-11-23 18:30:34,247 - INFO - ✓ API call successful. Remaining today: 7056
# 2025-11-23 18:30:34,762 - INFO - ✓ API call successful. Remaining today: 7055
# 2025-11-23 18:30:35,279 - INFO - ✓ API call successful. Remaining today: 7054
# 2025-11-23 18:30:35,794 - INFO - ✓ API call successful. Remaining today: 7053
# 2025-11-23 18:30:36,310 - INFO - ✓ API call successful. Remaining today: 7052
# 2025-11-23 18:30:36,825 - INFO - ✓ API call successful. Remaining today: 7051
# 2025-11-23 18:30:37,332 - INFO - ✓ API call successful. Remaining today: 7050
# 2025-11-23 18:30:37,860 - INFO - ✓ API call successful. Remaining today: 7049
# 2025-11-23 18:30:38,371 - INFO - ✓ API call successful. Remaining today: 7048
# 2025-11-23 18:30:38,891 - INFO - ✓ API call successful. Remaining today: 7047
# 2025-11-23 18:30:39,405 - INFO - ✓ API call successful. Remaining today: 7046
# 2025-11-23 18:30:39,919 - INFO - ✓ API call successful. Remaining today: 7045
# 2025-11-23 18:30:40,418 - INFO - ✓ API call successful. Remaining today: 7044
# 2025-11-23 18:30:40,928 - INFO - ✓ API call successful. Remaining today: 7043
# 2025-11-23 18:30:41,441 - INFO - ✓ API call successful. Remaining today: 7042
# 2025-11-23 18:30:41,950 - INFO - ✓ API call successful. Remaining today: 7041
# 2025-11-23 18:30:42,468 - INFO - ✓ API call successful. Remaining today: 7040
# 2025-11-23 18:30:43,032 - INFO - ✓ API call successful. Remaining today: 6923
# 2025-11-23 18:30:43,546 - INFO - ✓ API call successful. Remaining today: 6922
# 2025-11-23 18:30:44,049 - INFO - ✓ API call successful. Remaining today: 6921
# 2025-11-23 18:30:44,561 - INFO - ✓ API call successful. Remaining today: 6920
# 2025-11-23 18:30:45,076 - INFO - ✓ API call successful. Remaining today: 6919
# 2025-11-23 18:30:45,588 - INFO - ✓ API call successful. Remaining today: 6918
# 2025-11-23 18:30:46,095 - INFO - ✓ API call successful. Remaining today: 6917
# 2025-11-23 18:30:46,617 - INFO - ✓ API call successful. Remaining today: 6916
# 2025-11-23 18:30:47,125 - INFO - ✓ API call successful. Remaining today: 6915
# 2025-11-23 18:30:47,639 - INFO - ✓ API call successful. Remaining today: 6914
# 2025-11-23 18:30:48,150 - INFO - ✓ API call successful. Remaining today: 6913
# 2025-11-23 18:30:48,662 - INFO - ✓ API call successful. Remaining today: 6912
# 2025-11-23 18:30:49,173 - INFO - ✓ API call successful. Remaining today: 6911
# 2025-11-23 18:30:49,688 - INFO - ✓ API call successful. Remaining today: 6910
# 2025-11-23 18:30:50,202 - INFO - ✓ API call successful. Remaining today: 6909
# 2025-11-23 18:30:50,711 - INFO - ✓ API call successful. Remaining today: 6908
# 2025-11-23 18:30:51,225 - INFO - ✓ API call successful. Remaining today: 6907
# 2025-11-23 18:30:51,743 - INFO - ✓ API call successful. Remaining today: 6906
# 2025-11-23 18:30:52,258 - INFO - ✓ API call successful. Remaining today: 6905
# 2025-11-23 18:30:52,779 - INFO - ✓ API call successful. Remaining today: 6904
# 2025-11-23 18:30:53,294 - INFO - ✓ API call successful. Remaining today: 6903
# ...
# 2025-11-23 18:35:53,977 - INFO - ✓ API call successful. Remaining today: 6585
# 2025-11-23 18:35:54,482 - INFO - ✓ API call successful. Remaining today: 6584
# 2025-11-23 18:35:54,993 - INFO - ✓ API call successful. Remaining today: 6583
# 2025-11-23 18:35:55,505 - INFO - ✓ API call successful. Remaining today: 6582
# 2025-11-23 18:35:56,010 - INFO - ✓ API call successful. Remaining today: 6581
# 2025-11-23 18:35:56,509 - INFO - ✓ API call successful. Remaining today: 6580
# 2025-11-23 18:35:57,027 - INFO - ✓ API call successful. Remaining today: 6579
# 2025-11-23 18:35:57,544 - INFO - ✓ API call successful. Remaining today: 6578
# 2025-11-23 18:35:58,040 - INFO - ✓ API call successful. Remaining today: 6577
# 2025-11-23 18:35:58,568 - INFO - ✓ API call successful. Remaining today: 6576
# 2025-11-23 18:35:59,092 - INFO - ✓ API call successful. Remaining today: 6575
# 2025-11-23 18:35:59,592 - INFO - ✓ API call successful. Remaining today: 6574
# 2025-11-23 18:36:00,087 - INFO - ✓ API call successful. Remaining today: 6573
# 2025-11-23 18:36:00,658 - INFO - ✓ API call successful. Remaining today: 6689
# 2025-11-23 18:36:01,268 - INFO - ✓ API call successful. Remaining today: 6688
# 2025-11-23 18:36:01,776 - INFO - ✓ API call successful. Remaining today: 6687
# 2025-11-23 18:36:02,287 - INFO - ✓ API call successful. Remaining today: 6686
# 2025-11-23 18:36:02,794 - INFO - ✓ API call successful. Remaining today: 6685
# 2025-11-23 18:36:03,310 - INFO - ✓ API call successful. Remaining today: 6684
# 2025-11-23 18:36:03,818 - INFO - ✓ API call successful. Remaining today: 6683
# 2025-11-23 18:36:04,331 - INFO - ✓ API call successful. Remaining today: 6682
# 2025-11-23 18:36:04,836 - INFO - ✓ API call successful. Remaining today: 6681
# 2025-11-23 18:36:04,838 - INFO - Progress: 1050/1221 games (86.0%) | Speed: 1.7 games/sec | ETA: 1.7 min
# 2025-11-23 18:36:05,346 - INFO - ✓ API call successful. Remaining today: 6680
# 2025-11-23 18:36:05,852 - INFO - ✓ API call successful. Remaining today: 6679
# 2025-11-23 18:36:06,353 - INFO - ✓ API call successful. Remaining today: 6678
# 2025-11-23 18:36:06,866 - INFO - ✓ API call successful. Remaining today: 6677
# 2025-11-23 18:36:07,372 - INFO - ✓ API call successful. Remaining today: 6676
# 2025-11-23 18:36:07,890 - INFO - ✓ API call successful. Remaining today: 6675
# 2025-11-23 18:36:08,394 - INFO - ✓ API call successful. Remaining today: 6674
# 2025-11-23 18:36:08,903 - INFO - ✓ API call successful. Remaining today: 6673
# 2025-11-23 18:36:09,417 - INFO - ✓ API call successful. Remaining today: 6672
# 2025-11-23 18:36:09,930 - INFO - ✓ API call successful. Remaining today: 6671
# 2025-11-23 18:36:10,438 - INFO - ✓ API call successful. Remaining today: 6670
# 2025-11-23 18:36:10,941 - INFO - ✓ API call successful. Remaining today: 6669
# 2025-11-23 18:36:11,677 - INFO - ✓ API call successful. Remaining today: 6668
# 2025-11-23 18:36:12,178 - INFO - ✓ API call successful. Remaining today: 6667
# 2025-11-23 18:36:12,688 - INFO - ✓ API call successful. Remaining today: 6666
# 2025-11-23 18:36:13,194 - INFO - ✓ API call successful. Remaining today: 6665
# 2025-11-23 18:36:13,701 - INFO - ✓ API call successful. Remaining today: 6664
# 2025-11-23 18:36:14,205 - INFO - ✓ API call successful. Remaining today: 6663
# 2025-11-23 18:36:14,717 - INFO - ✓ API call successful. Remaining today: 6662
# 2025-11-23 18:36:15,460 - INFO - ✓ API call successful. Remaining today: 6661
# 2025-11-23 18:36:15,966 - INFO - ✓ API call successful. Remaining today: 6660
# 2025-11-23 18:36:16,470 - INFO - ✓ API call successful. Remaining today: 6659
# 2025-11-23 18:36:16,969 - INFO - ✓ API call successful. Remaining today: 6658
# 2025-11-23 18:36:17,486 - INFO - ✓ API call successful. Remaining today: 6657
# 2025-11-23 18:36:17,994 - INFO - ✓ API call successful. Remaining today: 6656
# 2025-11-23 18:36:18,490 - INFO - ✓ API call successful. Remaining today: 6655
# 2025-11-23 18:36:19,004 - INFO - ✓ API call successful. Remaining today: 6654
# 2025-11-23 18:36:19,521 - INFO - ✓ API call successful. Remaining today: 6653
# 2025-11-23 18:36:20,069 - INFO - ✓ API call successful. Remaining today: 6537
# 2025-11-23 18:36:20,580 - INFO - ✓ API call successful. Remaining today: 6536
# 2025-11-23 18:36:21,088 - INFO - ✓ API call successful. Remaining today: 6535
# 2025-11-23 18:36:21,590 - INFO - ✓ API call successful. Remaining today: 6534
# 2025-11-23 18:36:22,108 - INFO - ✓ API call successful. Remaining today: 6533
# 2025-11-23 18:36:22,611 - INFO - ✓ API call successful. Remaining today: 6532
# 2025-11-23 18:36:23,118 - INFO - ✓ API call successful. Remaining today: 6531
# 2025-11-23 18:36:23,631 - INFO - ✓ API call successful. Remaining today: 6530
# 2025-11-23 18:36:24,132 - INFO - ✓ API call successful. Remaining today: 6529
# 2025-11-23 18:36:24,668 - INFO - ✓ API call successful. Remaining today: 6528
# 2025-11-23 18:36:25,169 - INFO - ✓ API call successful. Remaining today: 6527
# 2025-11-23 18:36:25,682 - INFO - ✓ API call successful. Remaining today: 6526
# 2025-11-23 18:36:26,188 - INFO - ✓ API call successful. Remaining today: 6525
# 2025-11-23 18:36:26,738 - INFO - ✓ API call successful. Remaining today: 6524
# 2025-11-23 18:36:27,246 - INFO - ✓ API call successful. Remaining today: 6523
# 2025-11-23 18:36:27,765 - INFO - ✓ API call successful. Remaining today: 6522
# 2025-11-23 18:36:28,279 - INFO - ✓ API call successful. Remaining today: 6521
# 2025-11-23 18:36:28,782 - INFO - ✓ API call successful. Remaining today: 6520
# 2025-11-23 18:36:29,288 - INFO - ✓ API call successful. Remaining today: 6519
# 2025-11-23 18:36:29,796 - INFO - ✓ API call successful. Remaining today: 6518
# 2025-11-23 18:36:30,290 - INFO - ✓ API call successful. Remaining today: 6517
# 2025-11-23 18:36:30,793 - INFO - ✓ API call successful. Remaining today: 6516
# 2025-11-23 18:36:30,797 - INFO - Progress: 1100/1221 games (90.1%) | Speed: 1.7 games/sec | ETA: 1.2 min
# 2025-11-23 18:36:31,310 - INFO - ✓ API call successful. Remaining today: 6515
# 2025-11-23 18:36:31,829 - INFO - ✓ API call successful. Remaining today: 6514
# 2025-11-23 18:36:32,343 - INFO - ✓ API call successful. Remaining today: 6513
# 2025-11-23 18:36:32,866 - INFO - ✓ API call successful. Remaining today: 6512
# 2025-11-23 18:36:33,386 - INFO - ✓ API call successful. Remaining today: 6511
# 2025-11-23 18:36:33,966 - INFO - ✓ API call successful. Remaining today: 6510
# 2025-11-23 18:36:34,469 - INFO - ✓ API call successful. Remaining today: 6509
# 2025-11-23 18:36:34,975 - INFO - ✓ API call successful. Remaining today: 6508
# 2025-11-23 18:36:35,484 - INFO - ✓ API call successful. Remaining today: 6507
# 2025-11-23 18:36:35,994 - INFO - ✓ API call successful. Remaining today: 6506
# 2025-11-23 18:36:36,546 - INFO - ✓ API call successful. Remaining today: 6505
# 2025-11-23 18:36:37,130 - INFO - ✓ API call successful. Remaining today: 6504
# 2025-11-23 18:36:37,635 - INFO - ✓ API call successful. Remaining today: 6503
# 2025-11-23 18:36:38,142 - INFO - ✓ API call successful. Remaining today: 6502
# 2025-11-23 18:36:38,658 - INFO - ✓ API call successful. Remaining today: 6501
# 2025-11-23 18:36:39,170 - INFO - ✓ API call successful. Remaining today: 6500
# 2025-11-23 18:36:39,684 - INFO - ✓ API call successful. Remaining today: 6499
# 2025-11-23 18:36:40,195 - INFO - ✓ API call successful. Remaining today: 6498
# 2025-11-23 18:36:40,702 - INFO - ✓ API call successful. Remaining today: 6497
# 2025-11-23 18:36:41,210 - INFO - ✓ API call successful. Remaining today: 6496
# 2025-11-23 18:36:41,752 - INFO - ✓ API call successful. Remaining today: 6495
# 2025-11-23 18:36:42,259 - INFO - ✓ API call successful. Remaining today: 6494
# 2025-11-23 18:36:42,784 - INFO - ✓ API call successful. Remaining today: 6493
# 2025-11-23 18:36:43,294 - INFO - ✓ API call successful. Remaining today: 6492
# 2025-11-23 18:36:43,816 - INFO - ✓ API call successful. Remaining today: 6491
# 2025-11-23 18:36:44,328 - INFO - ✓ API call successful. Remaining today: 6490
# 2025-11-23 18:36:44,831 - INFO - ✓ API call successful. Remaining today: 6489
# 2025-11-23 18:36:45,342 - INFO - ✓ API call successful. Remaining today: 6488
# 2025-11-23 18:36:45,851 - INFO - ✓ API call successful. Remaining today: 6487
# 2025-11-23 18:36:46,367 - INFO - ✓ API call successful. Remaining today: 6486
# 2025-11-23 18:36:46,877 - INFO - ✓ API call successful. Remaining today: 6485
# 2025-11-23 18:36:47,385 - INFO - ✓ API call successful. Remaining today: 6484
# 2025-11-23 18:36:47,900 - INFO - ✓ API call successful. Remaining today: 6483
# 2025-11-23 18:36:48,481 - INFO - ✓ API call successful. Remaining today: 6482
# 2025-11-23 18:36:48,992 - INFO - ✓ API call successful. Remaining today: 6481
# 2025-11-23 18:36:49,496 - INFO - ✓ API call successful. Remaining today: 6480
# 2025-11-23 18:36:49,994 - INFO - ✓ API call successful. Remaining today: 6479
# 2025-11-23 18:36:50,508 - INFO - ✓ API call successful. Remaining today: 6478
# 2025-11-23 18:36:51,018 - INFO - ✓ API call successful. Remaining today: 6477
# 2025-11-23 18:36:51,521 - INFO - ✓ API call successful. Remaining today: 6476
# 2025-11-23 18:36:52,027 - INFO - ✓ API call successful. Remaining today: 6475
# 2025-11-23 18:36:52,542 - INFO - ✓ API call successful. Remaining today: 6474
# 2025-11-23 18:36:53,043 - INFO - ✓ API call successful. Remaining today: 6473
# 2025-11-23 18:36:53,537 - INFO - ✓ API call successful. Remaining today: 6472
# 2025-11-23 18:36:54,049 - INFO - ✓ API call successful. Remaining today: 6471
# 2025-11-23 18:36:54,563 - INFO - ✓ API call successful. Remaining today: 6470
# 2025-11-23 18:36:55,061 - INFO - ✓ API call successful. Remaining today: 6469
# 2025-11-23 18:36:55,568 - INFO - ✓ API call successful. Remaining today: 6468
# 2025-11-23 18:36:56,070 - INFO - ✓ API call successful. Remaining today: 6467
# 2025-11-23 18:36:56,570 - INFO - ✓ API call successful. Remaining today: 6466
# 2025-11-23 18:36:56,571 - INFO - Progress: 1150/1221 games (94.2%) | Speed: 1.7 games/sec | ETA: 0.7 min
# 2025-11-23 18:36:57,061 - INFO - ✓ API call successful. Remaining today: 6465
# 2025-11-23 18:36:57,610 - INFO - ✓ API call successful. Remaining today: 6464
# 2025-11-23 18:36:58,112 - INFO - ✓ API call successful. Remaining today: 6463
# 2025-11-23 18:36:58,622 - INFO - ✓ API call successful. Remaining today: 6462
# 2025-11-23 18:36:59,131 - INFO - ✓ API call successful. Remaining today: 6461
# 2025-11-23 18:36:59,693 - INFO - ✓ API call successful. Remaining today: 6460
# 2025-11-23 18:37:00,206 - INFO - ✓ API call successful. Remaining today: 6459
# 2025-11-23 18:37:00,716 - INFO - ✓ API call successful. Remaining today: 6574
# 2025-11-23 18:37:01,252 - INFO - ✓ API call successful. Remaining today: 6573
# 2025-11-23 18:37:01,767 - INFO - ✓ API call successful. Remaining today: 6572
# 2025-11-23 18:37:02,285 - INFO - ✓ API call successful. Remaining today: 6571
# 2025-11-23 18:37:02,809 - INFO - ✓ API call successful. Remaining today: 6570
# 2025-11-23 18:37:03,302 - INFO - ✓ API call successful. Remaining today: 6569
# 2025-11-23 18:37:03,823 - INFO - ✓ API call successful. Remaining today: 6568
# 2025-11-23 18:37:04,337 - INFO - ✓ API call successful. Remaining today: 6567
# 2025-11-23 18:37:04,849 - INFO - ✓ API call successful. Remaining today: 6566
# 2025-11-23 18:37:05,371 - INFO - ✓ API call successful. Remaining today: 6565
# 2025-11-23 18:37:05,881 - INFO - ✓ API call successful. Remaining today: 6564
# 2025-11-23 18:37:06,400 - INFO - ✓ API call successful. Remaining today: 6563
# 2025-11-23 18:37:06,913 - INFO - ✓ API call successful. Remaining today: 6562
# 2025-11-23 18:37:07,418 - INFO - ✓ API call successful. Remaining today: 6561
# 2025-11-23 18:37:07,925 - INFO - ✓ API call successful. Remaining today: 6560
# 2025-11-23 18:37:08,441 - INFO - ✓ API call successful. Remaining today: 6559
# 2025-11-23 18:37:08,954 - INFO - ✓ API call successful. Remaining today: 6558
# 2025-11-23 18:37:09,468 - INFO - ✓ API call successful. Remaining today: 6557
# 2025-11-23 18:37:09,967 - INFO - ✓ API call successful. Remaining today: 6556
# 2025-11-23 18:37:10,484 - INFO - ✓ API call successful. Remaining today: 6555
# 2025-11-23 18:37:10,981 - INFO - ✓ API call successful. Remaining today: 6554
# 2025-11-23 18:37:11,483 - INFO - ✓ API call successful. Remaining today: 6553
# 2025-11-23 18:37:11,995 - INFO - ✓ API call successful. Remaining today: 6552
# 2025-11-23 18:37:12,509 - INFO - ✓ API call successful. Remaining today: 6551
# 2025-11-23 18:37:13,029 - INFO - ✓ API call successful. Remaining today: 6550
# 2025-11-23 18:37:13,533 - INFO - ✓ API call successful. Remaining today: 6549
# 2025-11-23 18:37:14,046 - INFO - ✓ API call successful. Remaining today: 6548
# 2025-11-23 18:37:14,552 - INFO - ✓ API call successful. Remaining today: 6547
# 2025-11-23 18:37:15,062 - INFO - ✓ API call successful. Remaining today: 6546
# 2025-11-23 18:37:15,574 - INFO - ✓ API call successful. Remaining today: 6545
# 2025-11-23 18:37:16,078 - INFO - ✓ API call successful. Remaining today: 6544
# 2025-11-23 18:37:16,595 - INFO - ✓ API call successful. Remaining today: 6543
# 2025-11-23 18:37:17,103 - INFO - ✓ API call successful. Remaining today: 6542
# 2025-11-23 18:37:17,604 - INFO - ✓ API call successful. Remaining today: 6541
# 2025-11-23 18:37:18,115 - INFO - ✓ API call successful. Remaining today: 6540
# 2025-11-23 18:37:18,628 - INFO - ✓ API call successful. Remaining today: 6539
# 2025-11-23 18:37:19,140 - INFO - ✓ API call successful. Remaining today: 6538
# 2025-11-23 18:37:19,663 - INFO - ✓ API call successful. Remaining today: 6537
# 2025-11-23 18:37:20,213 - INFO - ✓ API call successful. Remaining today: 6419
# 2025-11-23 18:37:20,715 - INFO - ✓ API call successful. Remaining today: 6418
# 2025-11-23 18:37:21,224 - INFO - ✓ API call successful. Remaining today: 6417
# 2025-11-23 18:37:21,737 - INFO - ✓ API call successful. Remaining today: 6416
# 2025-11-23 18:37:22,247 - INFO - ✓ API call successful. Remaining today: 6415
# 2025-11-23 18:37:22,249 - INFO - Progress: 1200/1221 games (98.3%) | Speed: 1.7 games/sec | ETA: 0.2 min
# 2025-11-23 18:37:22,754 - INFO - ✓ API call successful. Remaining today: 6414
# 2025-11-23 18:37:23,267 - INFO - ✓ API call successful. Remaining today: 6413
# 2025-11-23 18:37:23,770 - INFO - ✓ API call successful. Remaining today: 6412
# 2025-11-23 18:37:24,280 - INFO - ✓ API call successful. Remaining today: 6411
# 2025-11-23 18:37:24,782 - INFO - ✓ API call successful. Remaining today: 6410
# 2025-11-23 18:37:25,284 - INFO - ✓ API call successful. Remaining today: 6409
# 2025-11-23 18:37:25,792 - INFO - ✓ API call successful. Remaining today: 6408
# 2025-11-23 18:37:26,303 - INFO - ✓ API call successful. Remaining today: 6407
# 2025-11-23 18:37:26,811 - INFO - ✓ API call successful. Remaining today: 6406
# 2025-11-23 18:37:27,344 - INFO - ✓ API call successful. Remaining today: 6405
# 2025-11-23 18:37:27,853 - INFO - ✓ API call successful. Remaining today: 6404
# 2025-11-23 18:37:28,352 - INFO - ✓ API call successful. Remaining today: 6403
# 2025-11-23 18:37:28,862 - INFO - ✓ API call successful. Remaining today: 6402
# 2025-11-23 18:37:29,561 - INFO - ✓ API call successful. Remaining today: 6401
# 2025-11-23 18:37:30,069 - INFO - ✓ API call successful. Remaining today: 6400
# 2025-11-23 18:37:30,573 - INFO - ✓ API call successful. Remaining today: 6399
# 2025-11-23 18:37:31,090 - INFO - ✓ API call successful. Remaining today: 6398
# 2025-11-23 18:37:31,596 - INFO - ✓ API call successful. Remaining today: 6397
# 2025-11-23 18:37:32,107 - INFO - ✓ API call successful. Remaining today: 6396
# 2025-11-23 18:37:32,613 - INFO - ✓ API call successful. Remaining today: 6395
# 2025-11-23 18:37:33,118 - INFO - ✓ API call successful. Remaining today: 6394
# 2025-11-23 18:37:33,121 - INFO - Progress: 1221/1221 games (100.0%) | Speed: 1.7 games/sec | ETA: 0.0 min
# 2025-11-23 18:37:33,273 - INFO -
# ✓ Player stats collected: 33503 records
# 2025-11-23 18:37:33,274 - INFO -   Total time: 11.9 minutes
# 2025-11-23 18:37:33,274 - INFO -
# Calculating team features...
# 2025-11-23 18:37:33,465 - INFO - ✓ Team features calculated: 2442 teams
# ✓ Feature calculation complete!
# Total team records: 2442
# Features calculated: 49

# %% [markdown]
# ## Step 4: Add Target Variable (team_won)
#
# **For XGBoost Binary Classification:**
# - `team_won = 1` if this team won the game
# - `team_won = 0` if this team lost the game
#
# Each game has 2 rows (one for each team), so the classes are naturally balanced 50/50.

# %%
# Merge with game metadata to get winning team info
final_df = team_features_df.merge(
    games_df[['game_id', 'season', 'winning_team_id', 'date']],
    on='game_id',
    how='left',
    suffixes=('', '_meta')
)

# Create binary target variable for XGBoost
# 1 = this team won, 0 = this team lost
final_df['team_won'] = (final_df['team_id'] == final_df['winning_team_id']).astype(int)

print(f"\n{'='*70}")
print(f"TARGET VARIABLE CREATED")
print(f"{'='*70}")
print(f"\nTarget variable: team_won")
print(f"  1 = Team won this game")
print(f"  0 = Team lost this game")
print(f"\nDistribution:")
print(final_df['team_won'].value_counts().to_dict())
print(f"\nBalance: {final_df['team_won'].value_counts()[1] / len(final_df) * 100:.1f}% wins")
print(f"✓ Perfectly balanced for binary classification!")
# Out:
# ======================================================================
# TARGET VARIABLE CREATED
# ======================================================================
#
# Target variable: team_won
#   1 = Team won this game
#   0 = Team lost this game
#
# Distribution:
# {0: 1221, 1: 1221}
#
# Balance: 50.0% wins
# ✓ Perfectly balanced for binary classification!

# %% [markdown]
# ## Step 5: Organize and Save Dataset

# %%
# Select columns for final dataset
# Order: identifiers, features, target

# Identify feature columns (exclude metadata)
exclude_cols = ['winning_team_id', 'season_meta']
feature_cols = [col for col in final_df.columns 
                if col not in ['game_id', 'team_id', 'season', 'team_name', 'date', 'team_won'] + exclude_cols]

# Create final column order
final_columns = [
    # Identifiers
    'season',
    'game_id', 
    'team_id',
    'team_name',
    'date'
] + feature_cols + [
    # Target variable (last column)
    'team_won'
]

ml_dataset = final_df[final_columns].copy()

print(f"\n{'='*70}")
print(f"FINAL DATASET STRUCTURE")
print(f"{'='*70}")
print(f"\nDataset shape: {ml_dataset.shape}")
print(f"  Rows (team-games): {len(ml_dataset)}")
print(f"  Columns: {len(ml_dataset.columns)}")
print(f"\nColumn breakdown:")
print(f"  Identifiers: 5 (season, game_id, team_id, team_name, date)")
print(f"  Features: {len(feature_cols)}")
print(f"  Target: 1 (team_won)")
print(f"\nFeatures included:")
for i, col in enumerate(feature_cols, 1):
    print(f"  {i:2d}. {col}")

print(f"\n{'='*70}")
# Out:
# ======================================================================
# FINAL DATASET STRUCTURE
# ======================================================================
#
# Dataset shape: (2442, 54)
#   Rows (team-games): 2442
#   Columns: 54
#
# Column breakdown:
#   Identifiers: 5 (season, game_id, team_id, team_name, date)
#   Features: 48
#   Target: 1 (team_won)
#
# Features included:
#    1. ft_pct_mean
#    2. fg_made_sum
#    3. fg_made_mean
#    4. fg_attempted_sum
#    5. fg_attempted_mean
#    6. three_made_sum
#    7. three_made_mean
#    8. three_attempted_sum
#    9. three_attempted_mean
#   10. ft_made_sum
#   11. ft_made_mean
#   12. ft_attempted_sum
#   13. ft_attempted_mean
#   14. minutes_sum
#   15. minutes_mean
#   16. minutes_max
#   17. points_sum
#   18. points_mean
#   19. points_std
#   20. points_max
#   21. assists_sum
#   22. assists_mean
#   23. assists_std
#   24. assists_max
#   25. total_rebounds_sum
#   26. total_rebounds_mean
#   27. total_rebounds_std
#   28. total_rebounds_max
#   29. offensive_reb_sum
#   30. offensive_reb_mean
#   31. defensive_reb_sum
#   32. defensive_reb_mean
#   33. steals_sum
#   34. steals_mean
#   35. blocks_sum
#   36. blocks_mean
#   37. turnovers_sum
#   38. turnovers_mean
#   39. personal_fouls_sum
#   40. personal_fouls_mean
#   41. plus_minus_sum
#   42. plus_minus_mean
#   43. fg_pct_mean
#   44. three_pct_mean
#   45. assist_to_turnover_ratio
#   46. three_point_rate
#   47. offensive_reb_rate
#   48. true_shooting_pct
#
# ======================================================================

# %% [markdown]
# ## Step 6: Data Quality Checks

# %%
print(f"\n{'='*70}")
print(f"DATA QUALITY CHECKS")
print(f"{'='*70}")

# 1. Missing values
print("\n1. Missing Values:")
missing = ml_dataset.isnull().sum()
if missing.sum() > 0:
    print(missing[missing > 0])
else:
    print("   ✓ No missing values!")

# 2. Games with 2 teams
print("\n2. Teams per Game:")
teams_per_game = ml_dataset.groupby('game_id').size()
if (teams_per_game == 2).all():
    print("   ✓ All games have exactly 2 teams!")
else:
    weird_games = teams_per_game[teams_per_game != 2]
    print(f"   ⚠️  {len(weird_games)} games with != 2 teams")
    print(weird_games)

# 3. Target balance
print("\n3. Target Variable Balance:")
wins = (ml_dataset['team_won'] == 1).sum()
losses = (ml_dataset['team_won'] == 0).sum()
print(f"   Wins: {wins}")
print(f"   Losses: {losses}")
print(f"   Difference: {abs(wins - losses)}")
if abs(wins - losses) <= 1:
    print("   ✓ Perfectly balanced!")
else:
    print(f"   ⚠️  Imbalance detected")

# 4. Feature statistics
print("\n4. Feature Value Ranges:")
print(ml_dataset[feature_cols].describe().T[['mean', 'std', 'min', 'max']].head(10))

# 5. Season verification
print(f"\n5. Season Verification:")
print(f"   Season: {ml_dataset['season'].unique()}")
print(f"   Games: {ml_dataset['game_id'].nunique()}")
print(f"   Date range: {ml_dataset['date'].min()} to {ml_dataset['date'].max()}")

print(f"\n{'='*70}")
# Out:
# ======================================================================
# DATA QUALITY CHECKS
# ======================================================================
#
# 1. Missing Values:
#    ✓ No missing values!
#
# 2. Teams per Game:
#    ✓ All games have exactly 2 teams!
#
# 3. Target Variable Balance:
#    Wins: 1221
#    Losses: 1221
#    Difference: 0
#    ✓ Perfectly balanced!
#
# 4. Feature Value Ranges:
#                            mean        std        min         max
# ft_pct_mean           42.599983  12.647668   6.000000   87.500000
# fg_made_sum           41.039722   5.262279  23.000000   68.000000
# fg_made_mean           3.893948   0.782006   1.666667    7.000000
# fg_attempted_sum      88.319410   6.824086  62.000000  115.000000
# fg_attempted_mean      8.380772   1.470407   4.411765   16.166667
# three_made_sum        12.714169   4.072595   2.000000   31.000000
# three_made_mean        1.203495   0.424274   0.142857    3.125000
# three_attempted_sum   34.748976   7.138850  10.000000   72.000000
# three_attempted_mean   3.292783   0.849300   1.000000    7.875000
# ft_made_sum           17.063882   5.812376   3.000000   38.000000
#
# 5. Season Verification:
#    Season: [2020]
#    Games: 1221
#    Date range: 2020-12-12T00:00:00.000Z to 2021-07-21T01:00:00.000Z
#
# ======================================================================

# %% [markdown]
# ## Step 7: Save to CSV

# %%
# Create filename with season
output_filename = f"nba_features_{SEASON_TO_PROCESS}.csv"
output_path = os.path.join(OUTPUT_DIR, output_filename)

# Save to CSV
ml_dataset.to_csv(output_path, index=False)

print(f"\n{'='*70}")
print(f"✅ DATASET SAVED SUCCESSFULLY!")
print(f"{'='*70}")
print(f"\nFile: {output_path}")
print(f"Size: {os.path.getsize(output_path) / 1024:.1f} KB")
print(f"\nDataset summary:")
print(f"  Season: {SEASON_TO_PROCESS}")
print(f"  Games: {ml_dataset['game_id'].nunique()}")
print(f"  Team-game records: {len(ml_dataset)}")
print(f"  Features: {len(feature_cols)}")
print(f"  Target: team_won (binary: 0=loss, 1=win)")

print(f"\n{'='*70}")
print(f"NEXT STEPS")
print(f"{'='*70}")
print(f"\n1. To process another season:")
print(f"   - Change SEASON_TO_PROCESS variable")
print(f"   - Re-run all cells")
print(f"\n2. After collecting all seasons (2018-2024):")
print(f"   - Combine CSVs: pd.concat([df_2018, df_2019, ..., df_2024])")
print(f"   - Split: train = seasons 2018-2023, test = season 2024")
print(f"   - Train XGBoost model")
print(f"\n3. For ML training:")
print(f"   X = df.drop(['game_id', 'team_id', 'team_name', 'date', 'team_won'], axis=1)")
print(f"   y = df['team_won']")
print(f"   # Keep 'season' column for train/test split!")
# Out:
# ======================================================================
# ✅ DATASET SAVED SUCCESSFULLY!
# ======================================================================
#
# File: nba_features_by_year/nba_features_2020.csv
# Size: 1340.4 KB
#
# Dataset summary:
#   Season: 2020
#   Games: 1221
#   Team-game records: 2442
#   Features: 48
#   Target: team_won (binary: 0=loss, 1=win)
#
# ======================================================================
# NEXT STEPS
# ======================================================================
#
# 1. To process another season:
#    - Change SEASON_TO_PROCESS variable
#    - Re-run all cells
#
# 2. After collecting all seasons (2018-2024):
#    - Combine CSVs: pd.concat([df_2018, df_2019, ..., df_2024])
#    - Split: train = seasons 2018-2023, test = season 2024
#    - Train XGBoost model
#
# 3. For ML training:
#    X = df.drop(['game_id', 'team_id', 'team_name', 'date', 'team_won'], axis=1)
#    y = df['team_won']
#    # Keep 'season' column for train/test split!

# %% [markdown]
# ## Sample of Final Dataset

# %%
print(f"\n{'='*70}")
print(f"SAMPLE DATA (First 5 Records)")
print(f"{'='*70}\n")

# Show first game (2 teams)
first_game_id = ml_dataset['game_id'].iloc[0]
sample = ml_dataset[ml_dataset['game_id'] == first_game_id]

print(f"Game ID: {first_game_id}")
print(f"\nTeam 1: {sample.iloc[0]['team_name']}")
print(f"  team_won: {sample.iloc[0]['team_won']} ({'WON' if sample.iloc[0]['team_won'] == 1 else 'LOST'})")
print(f"  points_sum: {sample.iloc[0]['points_sum']}")
print(f"  assists_sum: {sample.iloc[0]['assists_sum']}")
print(f"\nTeam 2: {sample.iloc[1]['team_name']}")
print(f"  team_won: {sample.iloc[1]['team_won']} ({'WON' if sample.iloc[1]['team_won'] == 1 else 'LOST'})")
print(f"  points_sum: {sample.iloc[1]['points_sum']}")
print(f"  assists_sum: {sample.iloc[1]['assists_sum']}")

print(f"\nFull dataframe preview:")
ml_dataset.head(4)
# Out:
# ======================================================================
# SAMPLE DATA (First 5 Records)
# ======================================================================
#
# Game ID: 7501
#
# Team 1: Boston Celtics
#   team_won: 0 (LOST)
#   points_sum: 89.0
#   assists_sum: 18.0
#
# Team 2: Brooklyn Nets
#   team_won: 1 (WON)
#   points_sum: 113.0
#   assists_sum: 26.0
#
# Full dataframe preview:
#    season  game_id  team_id             team_name                      date  \
# 0    2020     7501        2        Boston Celtics  2020-12-19T01:00:00.000Z
# 1    2020     7501        4         Brooklyn Nets  2020-12-19T01:00:00.000Z
# 2    2020     7502       21       Milwaukee Bucks  2020-12-19T01:00:00.000Z
# 3    2020     7502       23  New Orleans Pelicans  2020-12-19T01:00:00.000Z
#
#    ft_pct_mean  fg_made_sum  fg_made_mean  fg_attempted_sum  \
# 0    38.392857         32.0      2.285714              92.0
# 1    40.471429         38.0      2.714286              88.0
# 2    56.875000         38.0      2.375000              90.0
# 3    49.509091         44.0      4.000000              86.0
#
#    fg_attempted_mean  ...  personal_fouls_mean  plus_minus_sum  \
# 0           6.571429  ...             1.642857          -120.0
# 1           6.285714  ...             1.357143           120.0
# 2           5.625000  ...             2.000000           -70.0
# 3           7.818182  ...             2.272727            70.0
#
#    plus_minus_mean  fg_pct_mean  three_pct_mean  assist_to_turnover_ratio  \
# 0        -8.571429    31.585714       18.085714                  0.818182
# 1         8.571429    30.478571       28.364286                  1.300000
# 2        -4.375000    36.650000       16.043750                  1.235294
# 3         6.363636    53.663636       22.727273                  1.923077
#
#    three_point_rate  offensive_reb_rate  true_shooting_pct  team_won
# 0          0.250000            0.229167           0.439550         0
# 1          0.421053            0.150943           0.565679         1
# 2          0.263158            0.272727           0.547481         0
# 3          0.272727            0.294118           0.602696         1
#
# [4 rows x 54 columns]

# %% [markdown]
# ## Summary: How to Process All Seasons
#
# ### Step-by-Step Process:
#
# 1. **Process Season 2018**
#    ```python
#    SEASON_TO_PROCESS = 2018
#    # Run all cells
#    # Output: nba_features_by_year/nba_features_2018.csv
#    ```
#
# 2. **Process Season 2019**
#    ```python
#    SEASON_TO_PROCESS = 2019
#    # Run all cells
#    # Output: nba_features_by_year/nba_features_2019.csv
#    ```
#
# 3. **Repeat for 2020, 2021, 2022, 2023, 2024**
#
# 4. **Combine All Seasons** (After collecting all)
#    ```python
#    import pandas as pd
#    import glob
#
#    # Load all CSV files
#    all_files = glob.glob('nba_features_by_year/*.csv')
#    dfs = [pd.read_csv(f) for f in all_files]
#
#    # Combine
#    complete_df = pd.concat(dfs, ignore_index=True)
#
#    # Sort by season and game_id
#    complete_df = complete_df.sort_values(['season', 'game_id'])
#
#    # Save combined dataset
#    complete_df.to_csv('nba_features_2018_2024_complete.csv', index=False)
#
#    print(f"Complete dataset: {len(complete_df)} records")
#    print(f"Seasons: {sorted(complete_df['season'].unique())}")
#    print(f"Games: {complete_df['game_id'].nunique()}")
#    ```
#
# ### Timeline with 7,500 Requests/Day:
# - **Per season**: ~1,230 games = ~1,230 requests = 3-4 hours
# - **All 7 seasons**: Can be done in 1 day!
# - **Recommendation**: Process 2-3 seasons per day to be safe
#
# ### Target Variable Format:
# - **Column name**: `team_won`
# - **Data type**: Integer (0 or 1)
# - **Meaning**:
#   - `1` = This team WON the game
#   - `0` = This team LOST the game
# - **Perfect for XGBoost binary classification!**
